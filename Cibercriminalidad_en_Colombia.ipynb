# %% [markdown]
# <a href="https://colab.research.google.com/github/marcebm19/BOOTCAMP-1/blob/Rama-Practica/Cibercriminalidad_en_Colombia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# lee el archivo con el conjunto de datos de delitos informaticos y lo guarda en un DataFrame
df_delitos_informaticos = pd.read_csv('/content/drive/MyDrive/TRABAJO FINAL/Delitos_Informaticos_V1_20250228.csv')
df_delitos_informaticos = pd.DataFrame(df_delitos_informaticos)

# %% [markdown]
# ** Explorar la estructura del dataset**

# %%
#Ver las primeras filas
df_delitos_informaticos.head()  # Muestra las primeras 5 filas
# Out:
#   CRIMINALIDAD ES_ARCHIVO ES_PRECLUSIÓN    ESTADO  ETAPA_CASO      LEY  \
# 0           NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 1           NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 2           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 3           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 4           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
#
#   PAÍS_HECHO DEPARTAMENTO_HECHO MUNICIPIO_HECHO  \
# 0   Colombia          Santander   FLORIDABLANCA
# 1   Colombia      BOGOTÁ, D. C.    BOGOTÁ, D.C.
# 2   Colombia          Antioquia          ITAGUI
# 3   Colombia          Antioquia          ITAGUI
# 4   Colombia    Valle del Cauca            CALI
#
#                           SECCIONAL  AÑO_HECHOS  AÑO_ENTRADA AÑO_DENUNCIA  \
# 0  DIRECCIÓN SECCIONAL DE SANTANDER        2020         2020         2020
# 1     DIRECCIÓN SECCIONAL DE BOGOTÁ        2023         2023         2023
# 2   DIRECCIÓN SECCIONAL DE MEDELLÍN        2021         2021         2021
# 3   DIRECCIÓN SECCIONAL DE MEDELLÍN        2022         2022         2022
# 4       DIRECCIÓN SECCIONAL DE CALI        2021         2021         2021
#
#                                               DELITO          GRUPO_DELITO  \
# 0  VIOLACION DE DATOS PERSONALES ART 269F LEY 127...  DELITOS INFORMATICOS
# 1  VIOLACION DE DATOS PERSONALES ART 269F LEY 127...  DELITOS INFORMATICOS
# 2  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...  DELITOS INFORMATICOS
# 3  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...  DELITOS INFORMATICOS
# 4  TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...  DELITOS INFORMATICOS
#
#    CONSUMADO  TOTAL_PROCESOS
# 0  NO APLICA              50
# 1  NO APLICA             114
# 2  NO APLICA              31
# 3  NO APLICA             153
# 4  NO APLICA              61

# %%
# Ver la información general del dataset
df_delitos_informaticos.info()  # Muestra tipos de datos, valores nulos, etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55417 entries, 0 to 55416
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CRIMINALIDAD        55417 non-null  object
#  1   ES_ARCHIVO          55417 non-null  object
#  2   ES_PRECLUSIÓN       55417 non-null  object
#  3   ESTADO              55417 non-null  object
#  4   ETAPA_CASO          55417 non-null  object
#  5   LEY                 55417 non-null  object
#  6   PAÍS_HECHO          55417 non-null  object
#  7   DEPARTAMENTO_HECHO  55417 non-null  object
#  8   MUNICIPIO_HECHO     55417 non-null  object
#  9   SECCIONAL           55417 non-null  object
#  10  AÑO_HECHOS          55417 non-null  int64
#  11  AÑO_ENTRADA         55417 non-null  int64
#  12  AÑO_DENUNCIA        55417 non-null  object
#  13  DELITO              55417 non-null  object
#  14  GRUPO_DELITO        55417 non-null  object
#  15  CONSUMADO           55417 non-null  object
#  16  TOTAL_PROCESOS      55417 non-null  int64
# dtypes: int64(3), object(14)
# memory usage: 7.2+ MB

# %%
#Obtener estadísticas descriptivas
df_delitos_informaticos.describe(include="all") # Estadísticas generales (cuantitativas y cualitativas)
# Out:
#        CRIMINALIDAD ES_ARCHIVO ES_PRECLUSIÓN    ESTADO  ETAPA_CASO      LEY  \
# count         55417      55417         55417     55417       55417    55417
# unique            2          2             2         2           5        3
# top              SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# freq          43556      30354         54963     40705       51466    54961
# mean            NaN        NaN           NaN       NaN         NaN      NaN
# std             NaN        NaN           NaN       NaN         NaN      NaN
# min             NaN        NaN           NaN       NaN         NaN      NaN
# 25%             NaN        NaN           NaN       NaN         NaN      NaN
# 50%             NaN        NaN           NaN       NaN         NaN      NaN
# 75%             NaN        NaN           NaN       NaN         NaN      NaN
# max             NaN        NaN           NaN       NaN         NaN      NaN
#
#        PAÍS_HECHO DEPARTAMENTO_HECHO MUNICIPIO_HECHO  \
# count       55417              55417           55417
# unique          2                 34            1018
# top      Colombia          Antioquia    BOGOTÁ, D.C.
# freq        55406               7571            3481
# mean          NaN                NaN             NaN
# std           NaN                NaN             NaN
# min           NaN                NaN             NaN
# 25%           NaN                NaN             NaN
# 50%           NaN                NaN             NaN
# 75%           NaN                NaN             NaN
# max           NaN                NaN             NaN
#
#                                   SECCIONAL    AÑO_HECHOS   AÑO_ENTRADA  \
# count                                 55417  55417.000000  55417.000000
# unique                                   51           NaN           NaN
# top     DIRECCIÓN SECCIONAL DE CUNDINAMARCA           NaN           NaN
# freq                                   5515           NaN           NaN
# mean                                    NaN   2019.629789   2020.011838
# std                                     NaN      3.799876      3.715237
# min                                     NaN   2010.000000   2010.000000
# 25%                                     NaN   2017.000000   2018.000000
# 50%                                     NaN   2021.000000   2021.000000
# 75%                                     NaN   2023.000000   2023.000000
# max                                     NaN   2025.000000   2025.000000
#
#        AÑO_DENUNCIA                                             DELITO  \
# count         55417                                              55417
# unique           17                                                 67
# top            2024  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# freq           7854                                              17050
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                 GRUPO_DELITO  CONSUMADO  TOTAL_PROCESOS
# count                  55417      55417    55417.000000
# unique                     1          1             NaN
# top     DELITOS INFORMATICOS  NO APLICA             NaN
# freq                   55417      55417             NaN
# mean                     NaN        NaN        8.006298
# std                      NaN        NaN       88.801123
# min                      NaN        NaN        1.000000
# 25%                      NaN        NaN        1.000000
# 50%                      NaN        NaN        1.000000
# 75%                      NaN        NaN        2.000000
# max                      NaN        NaN     8715.000000

# %%
#Ver nombres de columnas
df_delitos_informaticos.columns
# Out:
# Index(['CRIMINALIDAD', 'ES_ARCHIVO', 'ES_PRECLUSIÓN', 'ESTADO', 'ETAPA_CASO',
#        'LEY', 'PAÍS_HECHO', 'DEPARTAMENTO_HECHO', 'MUNICIPIO_HECHO',
#        'SECCIONAL', 'AÑO_HECHOS', 'AÑO_ENTRADA', 'AÑO_DENUNCIA', 'DELITO',
#        'GRUPO_DELITO', 'CONSUMADO', 'TOTAL_PROCESOS'],
#       dtype='object')

# %% [markdown]
# Identificar valores nulos o **duplicados**

# %%
#Contar valores nulos por columna
df_delitos_informaticos.isnull().sum()
# Out:
# CRIMINALIDAD          0
# ES_ARCHIVO            0
# ES_PRECLUSIÓN         0
# ESTADO                0
# ETAPA_CASO            0
# LEY                   0
# PAÍS_HECHO            0
# DEPARTAMENTO_HECHO    0
# MUNICIPIO_HECHO       0
# SECCIONAL             0
# AÑO_HECHOS            0
# AÑO_ENTRADA           0
# AÑO_DENUNCIA          0
# DELITO                0
# GRUPO_DELITO          0
# CONSUMADO             0
# TOTAL_PROCESOS        0
# dtype: int64

# %%
#Verificar duplicados
df_delitos_informaticos.duplicated().sum()
# Out:
# np.int64(0)

# %%
#número de filas y columnas de un DataFrame
df_delitos_informaticos.shape
# Out:
# (55417, 17)

# %% [markdown]
# Identificar valores únicos en columnas

# %%
pd.unique(df_delitos_informaticos['CRIMINALIDAD'])
# Out:
# array(['NO', 'SI'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['ES_ARCHIVO'])
# Out:
# array(['SI', 'NO'], dtype=object)

# %%
pd.unique(df_delitos_informaticos["ES_PRECLUSIÓN"])
# Out:
# array(['NO', 'SI'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['ESTADO'])
# Out:
# array(['INACTIVO', 'ACTIVO'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['ETAPA_CASO'])
# Out:
# array(['INDAGACIÓN', 'EJECUCIÓN DE PENAS', 'INVESTIGACIÓN',
#        'TERMINACIÓN ANTICIPADA', 'JUICIO'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['LEY'])
# Out:
# array(['Ley 906', 'Ley 1098', 'Jurisdicción Menores'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['PAÍS_HECHO'])
# Out:
# array(['Colombia', 'SIN DATO'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['DEPARTAMENTO_HECHO'])
# Out:
# array(['Santander', 'BOGOTÁ, D. C.', 'Antioquia', 'Valle del Cauca',
#        'Quindío', 'Nariño', 'Huila', 'Cundinamarca', 'Norte de Santander',
#        'Caldas', 'Meta', 'Boyaca', 'Córdoba', 'Cesar', 'Cauca',
#        'Magdalena', 'Tolima', 'Risaralda', 'Bolívar', 'Sucre', 'Arauca',
#        'Atlántico', 'La Guajira',
#        'Archipiélago de San Andrés, Providencia y Santa Catalina',
#        'Caquetá', 'Putumayo', 'Chocó', 'Casanare', 'Guaviare', 'Amazonas',
#        'Guainía', 'Vichada', 'Vaupés', 'SIN DATO'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['MUNICIPIO_HECHO'])
# Out:
# array(['FLORIDABLANCA', 'BOGOTÁ, D.C.', 'ITAGUI', ..., 'CUÍTIVA',
#        'RÍO IRO', 'UBATÉ'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['SECCIONAL'])
# Out:
# array(['DIRECCIÓN SECCIONAL DE SANTANDER',
#        'DIRECCIÓN SECCIONAL DE BOGOTÁ', 'DIRECCIÓN SECCIONAL DE MEDELLÍN',
#        'DIRECCIÓN SECCIONAL DE CALI', 'DIRECCIÓN SECCIONAL DE QUINDÍO',
#        'DIRECCIÓN SECCIONAL DE NARIÑO', 'DIRECCIÓN SECCIONAL DE HUILA',
#        'DIRECCIÓN SECCIONAL DE ANTIOQUIA',
#        'DIRECCIÓN SECCIONAL DE CUNDINAMARCA',
#        'DIRECCIÓN SECCIONAL DE NORTE DE SANTANDER',
#        'DIRECCIÓN SECCIONAL DE CALDAS', 'DIRECCIÓN SECCIONAL DE META',
#        'DIRECCIÓN SECCIONAL DE TOLIMA', 'DIRECCIÓN SECCIONAL DE CÓRDOBA',
#        'DIRECCIÓN SECCIONAL DE CESAR', 'DIRECCIÓN SECCIONAL DE CAUCA',
#        'DIRECCIÓN SECCIONAL DE ATLÁNTICO',
#        'DIRECCIÓN SECCIONAL DE RISARALDA',
#        'DIRECCION ESPECIALIZADA CONTRA LOS DELITOS INFORMATICOS',
#        'DIRECCIÓN SECCIONAL DE BOYACÁ', 'DIRECCIÓN SECCIONAL DE BOLÍVAR',
#        'DIRECCIÓN SECCIONAL DE SUCRE', 'DIRECCIÓN SECCIONAL DE ARAUCA',
#        'DIRECCIÓN SECCIONAL DE MAGDALENA MEDIO',
#        'DIRECCIÓN SECCIONAL DE VALLE DEL CAUCA',
#        'DIRECCIÓN SECCIONAL DE LA GUAJIRA',
#        'DIRECCIÓN SECCIONAL DE MAGDALENA',
#        'DIRECCIÓN SECCIONAL DE SAN ANDRÉS, PROVIDENCIA Y SANTA CATALINA',
#        'DIRECCIÓN SECCIONAL DE CAQUETÁ', 'SIN DATO',
#        'DIRECCIÓN SECCIONAL DE PUTUMAYO', 'DIRECCIÓN SECCIONAL DE CHOCÓ',
#        'DIRECCIÓN SECCIONAL DE CASANARE',
#        'DIRECCIÓN ESPECIALIZADA CONTRA ORGANIZACIONES CRIMINALES',
#        'DIRECCION NACIONAL DEL CUERPO TECNICO DE INVESTIGACION',
#        'DIRECCIÓN SECCIONAL DE GUAVIARE',
#        'DIRECCIÓN SECCIONAL DE AMAZONAS',
#        'DELEGADA CONTRA LA CRIMINALIDAD ORGANIZADA',
#        'DIRECCIÓN SECCIONAL DE GUAINÍA - VAUPÉS',
#        'DIRECCIÓN DE FISCALÍA NACIONAL ESPECIALIZADA CONTRA EL TERRORISMO',
#        'DELEGADA ANTE LA CORTE SUPREMA DE JUSTICIA',
#        'DIRECCIÓN ESPECIALIZADA CONTRA LAS VIOLACIONES A LOS DERECHOS HUMANOS',
#        'DIRECCION ESPECIALIZADA CONTRA LA CORRUPCIÓN',
#        'DIRECCIÓN SECCIONAL DE VICHADA',
#        'DIRECCIÓN ESPECIALIZADA CONTRA EL LAVADO DE ACTIVOS',
#        'DIRECCIÓN ESPECIALIZADA DE INVESTIGACIONES FINANCIERAS - DEIF',
#        'DIRECCION ESPECIALIZADA PARA LOS DELITOS CONTRA LOS RECURSOS NATURALES Y EL MEDIO AMBIENTE',
#        'DIRECCIÓN ESPECIALIZADA CONTRA LOS DELITOS FISCALES',
#        'DIRECCIÓN DE JUSTICIA TRANSICIONAL',
#        'EJE TEMATICO - CIBERCRIMINALIDAD PROTECCION INFORMACION DATOS Y S I',
#        'EJE TEMATICO - CORRUPCIÓN ADMÓN JUSTICIA'], dtype=object)

# %%
pd.unique(df_delitos_informaticos['DELITO'])
# Out:
# array(['VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009',
#        'HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART. 269I LEY 1273 DE 2009',
#        'TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDOSE DE ALGUNA MANIPULACION INFORMATICA O ARTIFICIO SEMEJANTE ART. 269J LEY 1273 DE 2009',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'INTERCEPTACION DE DATOS INFORMATICOS, ART 269C LEY 1273 DE 2009',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009',
#        'MANIPULACION DE EQUIPOS MOVILES TERMINALES. ART 105 DE LEY 1453 DE 2.011',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, LA INTEGRIDAD Y LA DISPONIBILIDAD DE LOS DATOS Y DE LOS SISTEMAS INFORMATICOS',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8'],
#       dtype=object)

# %%
pd.unique(df_delitos_informaticos['GRUPO_DELITO'])
# Out:
# array(['DELITOS INFORMATICOS'], dtype=object)

# %%
(pd.unique(df_delitos_informaticos['AÑO_HECHOS']))
# Out:
# array([2020, 2023, 2021, 2022, 2011, 2019, 2014, 2024, 2013, 2018, 2017,
#        2016, 2015, 2010, 2025, 2012])

# %%
(pd.unique(df_delitos_informaticos['AÑO_ENTRADA']))
# Out:
# array([2020, 2023, 2021, 2022, 2012, 2019, 2014, 2024, 2013, 2017, 2016,
#        2015, 2018, 2010, 2025, 2011])

# %%
(pd.unique(df_delitos_informaticos['AÑO_DENUNCIA']))
# Out:
# array(['2020', '2023', '2021', '2022', '2012', '2019', '2014', '2024',
#        '2013', '2017', '2016', '2015', '2018', '2010', '2025', '2011',
#        'SIN DATO'], dtype=object)

# %% [markdown]
# Identificar y manejar valores faltantes

# %%
# AÑO_DENUNCIA maneja columnas con datos 'SIN DATO'
pd.unique(df_delitos_informaticos.AÑO_DENUNCIA)
# Out:
# array(['2020', '2023', '2021', '2022', '2012', '2019', '2014', '2024',
#        '2013', '2017', '2016', '2015', '2018', '2010', '2025', '2011',
#        'SIN DATO'], dtype=object)

# %%
# Total de valores encontrados 'SIN DATO'
df_delitos_informaticos['AÑO_DENUNCIA'].value_counts()
# Out:
# AÑO_DENUNCIA
# 2024        7854
# 2023        7262
# 2022        7060
# 2021        6057
# 2020        5162
# 2019        3701
# 2018        3592
# 2017        2638
# 2016        2173
# 2015        1845
# 2025        1711
# 2014        1606
# 2013        1509
# 2012        1217
# 2011        1174
# 2010         847
# SIN DATO       9
# Name: count, dtype: int64

# %%
df_delitos_informaticos.groupby("PAÍS_HECHO").size()
# Out:
# PAÍS_HECHO
# Colombia    55406
# SIN DATO       11
# dtype: int64

# %%
#Se decide reemplazar "Sin dato" por nulo.
df_delitos_informaticos[df_delitos_informaticos['PAÍS_HECHO'] == 'SIN DATO']
# Out:
#       CRIMINALIDAD ES_ARCHIVO ES_PRECLUSIÓN    ESTADO  ETAPA_CASO      LEY  \
# 5032            NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 9513            SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 27789           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 32084           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 33884           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 34020           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 38632           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 41291           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 46181           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 51016           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 53907           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
#
#       PAÍS_HECHO DEPARTAMENTO_HECHO MUNICIPIO_HECHO  \
# 5032    SIN DATO           SIN DATO        SIN DATO
# 9513    SIN DATO           SIN DATO        SIN DATO
# 27789   SIN DATO           SIN DATO        SIN DATO
# 32084   SIN DATO           SIN DATO        SIN DATO
# 33884   SIN DATO           SIN DATO        SIN DATO
# 34020   SIN DATO           SIN DATO        SIN DATO
# 38632   SIN DATO           SIN DATO        SIN DATO
# 41291   SIN DATO           SIN DATO        SIN DATO
# 46181   SIN DATO           SIN DATO        SIN DATO
# 51016   SIN DATO           SIN DATO        SIN DATO
# 53907   SIN DATO           SIN DATO        SIN DATO
#
#                                     SECCIONAL  AÑO_HECHOS  AÑO_ENTRADA  \
# 5032         DIRECCIÓN SECCIONAL DE ATLÁNTICO        2024         2024
# 9513         DIRECCIÓN SECCIONAL DE ATLÁNTICO        2024         2024
# 27789           DIRECCIÓN SECCIONAL DE BOGOTÁ        2018         2018
# 32084         DIRECCIÓN SECCIONAL DE MEDELLÍN        2024         2024
# 33884            DIRECCIÓN SECCIONAL DE SUCRE        2024         2024
# 34020         DIRECCIÓN SECCIONAL DE MEDELLÍN        2024         2024
# 38632         DIRECCIÓN SECCIONAL DE MEDELLÍN        2024         2024
# 41291  DIRECCIÓN SECCIONAL DE MAGDALENA MEDIO        2024         2024
# 46181           DIRECCIÓN SECCIONAL DE BOGOTÁ        2018         2018
# 51016        DIRECCIÓN SECCIONAL DE ATLÁNTICO        2024         2024
# 53907                                SIN DATO        2025         2025
#
#       AÑO_DENUNCIA                                             DELITO  \
# 5032      SIN DATO  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 9513      SIN DATO  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 27789         2018  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...
# 32084     SIN DATO  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...
# 33884     SIN DATO  MANIPULACION DE EQUIPOS MOVILES TERMINALES. AR...
# 34020     SIN DATO  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 38632     SIN DATO  SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS...
# 41291     SIN DATO  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...
# 46181         2018  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 51016     SIN DATO  DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS
# 53907     SIN DATO  TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...
#
#                GRUPO_DELITO  CONSUMADO  TOTAL_PROCESOS
# 5032   DELITOS INFORMATICOS  NO APLICA               2
# 9513   DELITOS INFORMATICOS  NO APLICA               2
# 27789  DELITOS INFORMATICOS  NO APLICA               3
# 32084  DELITOS INFORMATICOS  NO APLICA               2
# 33884  DELITOS INFORMATICOS  NO APLICA               1
# 34020  DELITOS INFORMATICOS  NO APLICA               2
# 38632  DELITOS INFORMATICOS  NO APLICA               1
# 41291  DELITOS INFORMATICOS  NO APLICA               1
# 46181  DELITOS INFORMATICOS  NO APLICA               1
# 51016  DELITOS INFORMATICOS  NO APLICA               2
# 53907  DELITOS INFORMATICOS  NO APLICA               1

# %%
df_delitos_informaticos_corregido[df_delitos_informaticos_corregido['PAÍS_HECHO'].isna()]
# Out:
#       CRIMINALIDAD ES_ARCHIVO ES_PRECLUSIÓN    ESTADO  ETAPA_CASO      LEY  \
# 5032            NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 9513            SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 27789           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 32084           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 33884           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 34020           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 38632           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 41291           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 46181           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 51016           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 53907           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
#
#       PAÍS_HECHO DEPARTAMENTO_HECHO MUNICIPIO_HECHO  \
# 5032         NaN                NaN             NaN
# 9513         NaN                NaN             NaN
# 27789        NaN                NaN             NaN
# 32084        NaN                NaN             NaN
# 33884        NaN                NaN             NaN
# 34020        NaN                NaN             NaN
# 38632        NaN                NaN             NaN
# 41291        NaN                NaN             NaN
# 46181        NaN                NaN             NaN
# 51016        NaN                NaN             NaN
# 53907        NaN                NaN             NaN
#
#                                     SECCIONAL  AÑO_HECHOS  AÑO_ENTRADA  \
# 5032         DIRECCIÓN SECCIONAL DE ATLÁNTICO        2024         2024
# 9513         DIRECCIÓN SECCIONAL DE ATLÁNTICO        2024         2024
# 27789           DIRECCIÓN SECCIONAL DE BOGOTÁ        2018         2018
# 32084         DIRECCIÓN SECCIONAL DE MEDELLÍN        2024         2024
# 33884            DIRECCIÓN SECCIONAL DE SUCRE        2024         2024
# 34020         DIRECCIÓN SECCIONAL DE MEDELLÍN        2024         2024
# 38632         DIRECCIÓN SECCIONAL DE MEDELLÍN        2024         2024
# 41291  DIRECCIÓN SECCIONAL DE MAGDALENA MEDIO        2024         2024
# 46181           DIRECCIÓN SECCIONAL DE BOGOTÁ        2018         2018
# 51016        DIRECCIÓN SECCIONAL DE ATLÁNTICO        2024         2024
# 53907                                     NaN        2025         2025
#
#       AÑO_DENUNCIA                                             DELITO  \
# 5032           NaN  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 9513           NaN  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 27789         2018  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...
# 32084          NaN  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...
# 33884          NaN  MANIPULACION DE EQUIPOS MOVILES TERMINALES. AR...
# 34020          NaN  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 38632          NaN  SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS...
# 41291          NaN  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...
# 46181         2018  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 51016          NaN  DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS
# 53907          NaN  TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...
#
#                GRUPO_DELITO  CONSUMADO  TOTAL_PROCESOS
# 5032   DELITOS INFORMATICOS  NO APLICA               2
# 9513   DELITOS INFORMATICOS  NO APLICA               2
# 27789  DELITOS INFORMATICOS  NO APLICA               3
# 32084  DELITOS INFORMATICOS  NO APLICA               2
# 33884  DELITOS INFORMATICOS  NO APLICA               1
# 34020  DELITOS INFORMATICOS  NO APLICA               2
# 38632  DELITOS INFORMATICOS  NO APLICA               1
# 41291  DELITOS INFORMATICOS  NO APLICA               1
# 46181  DELITOS INFORMATICOS  NO APLICA               1
# 51016  DELITOS INFORMATICOS  NO APLICA               2
# 53907  DELITOS INFORMATICOS  NO APLICA               1

# %%
df_delitos_informaticos_corregido = df_delitos_informaticos.replace('SIN DATO', np.nan) #revisar Columnas SIN DATO
df_delitos_informaticos_corregido
# Out:
#       CRIMINALIDAD ES_ARCHIVO ES_PRECLUSIÓN    ESTADO  ETAPA_CASO      LEY  \
# 0               NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 1               NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 2               SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 3               SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 4               SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# ...            ...        ...           ...       ...         ...      ...
# 55412           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 55413           NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 55414           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 55415           SI         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 55416           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
#
#       PAÍS_HECHO DEPARTAMENTO_HECHO MUNICIPIO_HECHO  \
# 0       Colombia          Santander   FLORIDABLANCA
# 1       Colombia      BOGOTÁ, D. C.    BOGOTÁ, D.C.
# 2       Colombia          Antioquia          ITAGUI
# 3       Colombia          Antioquia          ITAGUI
# 4       Colombia    Valle del Cauca            CALI
# ...          ...                ...             ...
# 55412   Colombia              Sucre       SINCELEJO
# 55413   Colombia             Caldas       LA DORADA
# 55414   Colombia              Sucre       SINCELEJO
# 55415   Colombia          Santander          GÜEPSA
# 55416   Colombia       Cundinamarca        GIRARDOT
#
#                                  SECCIONAL  AÑO_HECHOS  AÑO_ENTRADA  \
# 0         DIRECCIÓN SECCIONAL DE SANTANDER        2020         2020
# 1            DIRECCIÓN SECCIONAL DE BOGOTÁ        2023         2023
# 2          DIRECCIÓN SECCIONAL DE MEDELLÍN        2021         2021
# 3          DIRECCIÓN SECCIONAL DE MEDELLÍN        2022         2022
# 4              DIRECCIÓN SECCIONAL DE CALI        2021         2021
# ...                                    ...         ...          ...
# 55412         DIRECCIÓN SECCIONAL DE SUCRE        2022         2022
# 55413        DIRECCIÓN SECCIONAL DE CALDAS        2021         2021
# 55414         DIRECCIÓN SECCIONAL DE SUCRE        2016         2016
# 55415     DIRECCIÓN SECCIONAL DE SANTANDER        2018         2018
# 55416  DIRECCIÓN SECCIONAL DE CUNDINAMARCA        2023         2023
#
#       AÑO_DENUNCIA                                             DELITO  \
# 0             2020  VIOLACION DE DATOS PERSONALES ART 269F LEY 127...
# 1             2023  VIOLACION DE DATOS PERSONALES ART 269F LEY 127...
# 2             2021  ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...
# 3             2022  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 4             2021  TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...
# ...            ...                                                ...
# 55412         2022  SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS...
# 55413         2021  VIOLACION DE DATOS PERSONALES ART 269F LEY 127...
# 55414         2016  INTERCEPTACION DE DATOS INFORMATICOS ART 269C ...
# 55415         2018  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...
# 55416         2023  OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMAT...
#
#                GRUPO_DELITO  CONSUMADO  TOTAL_PROCESOS
# 0      DELITOS INFORMATICOS  NO APLICA              50
# 1      DELITOS INFORMATICOS  NO APLICA             114
# 2      DELITOS INFORMATICOS  NO APLICA              31
# 3      DELITOS INFORMATICOS  NO APLICA             153
# 4      DELITOS INFORMATICOS  NO APLICA              61
# ...                     ...        ...             ...
# 55412  DELITOS INFORMATICOS  NO APLICA               1
# 55413  DELITOS INFORMATICOS  NO APLICA               1
# 55414  DELITOS INFORMATICOS  NO APLICA               1
# 55415  DELITOS INFORMATICOS  NO APLICA               1
# 55416  DELITOS INFORMATICOS  NO APLICA               1
#
# [55417 rows x 17 columns]

# %% [markdown]
# Corregir errores en los datos

# %%
# Agrupar la columna DELITO para poder trabajar esta variable más fácil
pd.unique(df_delitos_informaticos['DELITO'])
# Out:
# array(['VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009',
#        'HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART. 269I LEY 1273 DE 2009',
#        'TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDOSE DE ALGUNA MANIPULACION INFORMATICA O ARTIFICIO SEMEJANTE ART. 269J LEY 1273 DE 2009',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'INTERCEPTACION DE DATOS INFORMATICOS, ART 269C LEY 1273 DE 2009',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009',
#        'MANIPULACION DE EQUIPOS MOVILES TERMINALES. ART 105 DE LEY 1453 DE 2.011',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, LA INTEGRIDAD Y LA DISPONIBILIDAD DE LOS DATOS Y DE LOS SISTEMAS INFORMATICOS',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR REALIZARSE SOBRE REDES O SISTEMAS INFORMATICOS O DE COMUNICACIONES ESTATALES U OFICIALES O DEL SECTOR FINANCIERO, NACIONALES O EXTRANJEROS ART. 269H N1',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'VIOLACION DE DATOS PERSONALES ART 269F LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 269A LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR OBTENER PROVECHO PARA SI O PARA UN TERCERO. ART. 269H N5',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR APROVECHARSE DE LA CONFIANZA DEPOSITADA POR EL POSEEDOR DE LA INFORMACION O POR QUIEN TUVIERE UN VINCULO CONTRACTUAL CON ESTE. ART. 269H N3',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR UTILIZAR COMO INSTRUMENTO A UN TERCERO DE BUENA FE ART. 269H N7',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'DAÑO INFORMATICO ART 269D LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES ART 269G LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR SER CON FINES TERRORISTAS O GENERANDO RIESGO PARA LA SEGURIDAD O DEFENSA NACIONAL. ART. 269H N6',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION ART 269B LEY 1273 DE 2009, AGRAVADO POR REVELAR O DAR A CONOCER EL CONTENIDO DE LA INFORMACION EN PERJUICIO DE OTRO ART. 269H N4',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8',
#        'USO DE SOFTWARE MALICIOSO ART 269E LEY 1273 DE 2009, AGRAVADO POR SER COMETIDO POR SERVIDOR PUBLICO EN EJERCICIO DE SUS FUNCIONES ART. 269H N2',
#        'INTERCEPTACION DE DATOS INFORMATICOS ART 269C LEY 1273 DE 2009 AGRAVADO POR SER COMETIDO POR EL RESPONSABLE DE LA ADMINISTRACION, MANEJO O CONTROL DE DICHA INFORMACION. ART. 269H N8'],
#       dtype=object)

# %%
#crear un dataframe con la variable
df_delito4 = df_delitos_informaticos_corregido.loc[:, ["CRIMINALIDAD",'ES_ARCHIVO','ESTADO','ETAPA_CASO','LEY','PAÍS_HECHO','SECCIONAL','DELITO','AÑO_ENTRADA','AÑO_DENUNCIA','GRUPO_DELITO','CONSUMADO','AÑO_HECHOS','DEPARTAMENTO_HECHO','MUNICIPIO_HECHO','TOTAL_PROCESOS','ES_PRECLUSIÓN']]
df_delito4
# Out:
#       CRIMINALIDAD ES_ARCHIVO    ESTADO  ETAPA_CASO      LEY PAÍS_HECHO  \
# 0               NO         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 1               NO         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 2               SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 3               SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 4               SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# ...            ...        ...       ...         ...      ...        ...
# 55412           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55413           NO         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55414           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55415           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55416           SI         NO    ACTIVO  INDAGACIÓN  Ley 906   Colombia
#
#                                  SECCIONAL  \
# 0         DIRECCIÓN SECCIONAL DE SANTANDER
# 1            DIRECCIÓN SECCIONAL DE BOGOTÁ
# 2          DIRECCIÓN SECCIONAL DE MEDELLÍN
# 3          DIRECCIÓN SECCIONAL DE MEDELLÍN
# 4              DIRECCIÓN SECCIONAL DE CALI
# ...                                    ...
# 55412         DIRECCIÓN SECCIONAL DE SUCRE
# 55413        DIRECCIÓN SECCIONAL DE CALDAS
# 55414         DIRECCIÓN SECCIONAL DE SUCRE
# 55415     DIRECCIÓN SECCIONAL DE SANTANDER
# 55416  DIRECCIÓN SECCIONAL DE CUNDINAMARCA
#
#                                                   DELITO  AÑO_ENTRADA  \
# 0      VIOLACION DE DATOS PERSONALES ART 269F LEY 127...         2020
# 1      VIOLACION DE DATOS PERSONALES ART 269F LEY 127...         2023
# 2      ACCESO ABUSIVO A UN SISTEMA INFORMATICO ART 26...         2021
# 3      HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...         2022
# 4      TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...         2021
# ...                                                  ...          ...
# 55412  SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS...         2022
# 55413  VIOLACION DE DATOS PERSONALES ART 269F LEY 127...         2021
# 55414  INTERCEPTACION DE DATOS INFORMATICOS ART 269C ...         2016
# 55415  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES ART...         2018
# 55416  OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMAT...         2023
#
#       AÑO_DENUNCIA          GRUPO_DELITO  CONSUMADO  AÑO_HECHOS  \
# 0             2020  DELITOS INFORMATICOS  NO APLICA        2020
# 1             2023  DELITOS INFORMATICOS  NO APLICA        2023
# 2             2021  DELITOS INFORMATICOS  NO APLICA        2021
# 3             2022  DELITOS INFORMATICOS  NO APLICA        2022
# 4             2021  DELITOS INFORMATICOS  NO APLICA        2021
# ...            ...                   ...        ...         ...
# 55412         2022  DELITOS INFORMATICOS  NO APLICA        2022
# 55413         2021  DELITOS INFORMATICOS  NO APLICA        2021
# 55414         2016  DELITOS INFORMATICOS  NO APLICA        2016
# 55415         2018  DELITOS INFORMATICOS  NO APLICA        2018
# 55416         2023  DELITOS INFORMATICOS  NO APLICA        2023
#
#       DEPARTAMENTO_HECHO MUNICIPIO_HECHO  TOTAL_PROCESOS ES_PRECLUSIÓN
# 0              Santander   FLORIDABLANCA              50            NO
# 1          BOGOTÁ, D. C.    BOGOTÁ, D.C.             114            NO
# 2              Antioquia          ITAGUI              31            NO
# 3              Antioquia          ITAGUI             153            NO
# 4        Valle del Cauca            CALI              61            NO
# ...                  ...             ...             ...           ...
# 55412              Sucre       SINCELEJO               1            NO
# 55413             Caldas       LA DORADA               1            NO
# 55414              Sucre       SINCELEJO               1            NO
# 55415          Santander          GÜEPSA               1            NO
# 55416       Cundinamarca        GIRARDOT               1            NO
#
# [55417 rows x 17 columns]

# %%
# Primero, vamos a limpiar la columna DELITO de las descripciones y artículos adicionales
df_delito4['DELITO'] = df_delito4['DELITO'].str.replace(r'\s*(ART\.?|LEY).*', '', regex=True).str.replace(r'[.,]$', '', regex=True).str.strip()
df_delito4
# Out:
#       CRIMINALIDAD ES_ARCHIVO    ESTADO  ETAPA_CASO      LEY PAÍS_HECHO  \
# 0               NO         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 1               NO         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 2               SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 3               SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 4               SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# ...            ...        ...       ...         ...      ...        ...
# 55412           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55413           NO         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55414           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55415           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 55416           SI         NO    ACTIVO  INDAGACIÓN  Ley 906   Colombia
#
#                                  SECCIONAL  \
# 0         DIRECCIÓN SECCIONAL DE SANTANDER
# 1            DIRECCIÓN SECCIONAL DE BOGOTÁ
# 2          DIRECCIÓN SECCIONAL DE MEDELLÍN
# 3          DIRECCIÓN SECCIONAL DE MEDELLÍN
# 4              DIRECCIÓN SECCIONAL DE CALI
# ...                                    ...
# 55412         DIRECCIÓN SECCIONAL DE SUCRE
# 55413        DIRECCIÓN SECCIONAL DE CALDAS
# 55414         DIRECCIÓN SECCIONAL DE SUCRE
# 55415     DIRECCIÓN SECCIONAL DE SANTANDER
# 55416  DIRECCIÓN SECCIONAL DE CUNDINAMARCA
#
#                                                   DELITO  AÑO_ENTRADA  \
# 0                          VIOLACION DE DATOS PERSONALES         2020
# 1                          VIOLACION DE DATOS PERSONALES         2023
# 2                ACCESO ABUSIVO A UN SISTEMA INFORMATICO         2021
# 3             HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2022
# 4      TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...         2021
# ...                                                  ...          ...
# 55412  SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS...         2022
# 55413                      VIOLACION DE DATOS PERSONALES         2021
# 55414               INTERCEPTACION DE DATOS INFORMATICOS         2016
# 55415         HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2018
# 55416  OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMAT...         2023
#
#       AÑO_DENUNCIA          GRUPO_DELITO  CONSUMADO  AÑO_HECHOS  \
# 0             2020  DELITOS INFORMATICOS  NO APLICA        2020
# 1             2023  DELITOS INFORMATICOS  NO APLICA        2023
# 2             2021  DELITOS INFORMATICOS  NO APLICA        2021
# 3             2022  DELITOS INFORMATICOS  NO APLICA        2022
# 4             2021  DELITOS INFORMATICOS  NO APLICA        2021
# ...            ...                   ...        ...         ...
# 55412         2022  DELITOS INFORMATICOS  NO APLICA        2022
# 55413         2021  DELITOS INFORMATICOS  NO APLICA        2021
# 55414         2016  DELITOS INFORMATICOS  NO APLICA        2016
# 55415         2018  DELITOS INFORMATICOS  NO APLICA        2018
# 55416         2023  DELITOS INFORMATICOS  NO APLICA        2023
#
#       DEPARTAMENTO_HECHO MUNICIPIO_HECHO  TOTAL_PROCESOS ES_PRECLUSIÓN
# 0              Santander   FLORIDABLANCA              50            NO
# 1          BOGOTÁ, D. C.    BOGOTÁ, D.C.             114            NO
# 2              Antioquia          ITAGUI              31            NO
# 3              Antioquia          ITAGUI             153            NO
# 4        Valle del Cauca            CALI              61            NO
# ...                  ...             ...             ...           ...
# 55412              Sucre       SINCELEJO               1            NO
# 55413             Caldas       LA DORADA               1            NO
# 55414              Sucre       SINCELEJO               1            NO
# 55415          Santander          GÜEPSA               1            NO
# 55416       Cundinamarca        GIRARDOT               1            NO
#
# [55417 rows x 17 columns]

# %%
#validar que la limpieza quede correcta
pd.unique(df_delito4['DELITO'])
# Out:
# array(['VIOLACION DE DATOS PERSONALES',
#        'ACCESO ABUSIVO A UN SISTEMA INFORMATICO',
#        'HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES',
#        'TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDOSE DE ALGUNA MANIPULACION INFORMATICA O',
#        'INTERCEPTACION DE DATOS INFORMATICOS',
#        'SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES',
#        'OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION',
#        'DAÑO INFORMATICO', 'MANIPULACION DE EQUIPOS MOVILES TERMINALES',
#        'USO DE SOFTWARE MALICIOSO',
#        'DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES',
#        'DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, LA INTEGRIDAD Y LA DISPONIBILIDAD DE LOS DATOS Y DE LOS SISTEMAS INFORMATICOS',
#        'DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS'], dtype=object)

# %% [markdown]
# **Agrupar datos para identificar patrones y tendencias**

# %%
#Agrupar delitos por año para ver cómo ha evolucionado la cantidad de delitos informáticos en el tiempo
tendencias_por_año = df_delitos_informaticos_corregido.groupby('AÑO_HECHOS')['TOTAL_PROCESOS'].sum().reset_index()

# Filtrar los datos para excluir el año 2025
df_filtrado = df_delitos_informaticos_corregido[df_delitos_informaticos_corregido['AÑO_HECHOS'] != 2025]

# Agrupar por año y contar el total de procesos
tendencias_por_año = df_filtrado.groupby('AÑO_HECHOS')['TOTAL_PROCESOS',].sum().reset_index()

# Calcular el porcentaje de variación respecto al año anterior
tendencias_por_año['VARIACION_%'] = tendencias_por_año['TOTAL_PROCESOS'].pct_change() * 100

# Formatear la columna para que muestre dos decimales y el símbolo '%'
tendencias_por_año['VARIACION_%'] = tendencias_por_año['VARIACION_%'].apply(lambda x: f"{x:.2f}%" if not pd.isna(x) else "")

# Ver el resultado
print(tendencias_por_año)
# Out:
#     AÑO_HECHOS  TOTAL_PROCESOS VARIACION_%
# 0         2010            5465
# 1         2011            5990       9.61%
# 2         2012            6757      12.80%
# 3         2013            9225      36.53%
# 4         2014            9338       1.22%
# 5         2015           10048       7.60%
# 6         2016           11980      19.23%
# 7         2017           15090      25.96%
# 8         2018           22620      49.90%
# 9         2019           24291       7.39%
# 10        2020           41465      70.70%
# 11        2021           48665      17.36%
# 12        2022           67653      39.02%
# 13        2023           73688       8.92%
# 14        2024           86938      17.98%

# %% [markdown]
# ## **Tendencia de delitos a lo largo del tiempo**

# %%
import plotly.express as px

# Asegurar que la columna 'VARIACION_%' sea numérica (sin %)
tendencias_por_año['VARIACION_%'] = tendencias_por_año['TOTAL_PROCESOS'].pct_change() * 100

# Crear gráfico interactivo
fig = px.line(
    tendencias_por_año,
    x='AÑO_HECHOS',
    y='TOTAL_PROCESOS',
    title='Tendencia y Variación de Total Procesos de Delitos Informáticos por Año',
    labels={'AÑO_HECHOS': 'Año', 'TOTAL_PROCESOS': 'Número Total de Procesos'},
    markers=True
)

# Personalizar el diseño y quitar la "k" del eje Y
fig.update_traces(
    line=dict(color='teal', width=2),
    hovertemplate="<b>Año:</b> %{x}<br>" +
                  "<b>Total Procesos:</b> %{y:,}<br>" +  # Formato con comas
                  "<b>Variación:</b> %{customdata:.2f}%",  # Variación porcentual
    customdata=tendencias_por_año['VARIACION_%']  # Enviar valores de variación como 'customdata'
)

fig.update_layout(
    hovermode='x unified',
    template='plotly_dark',
    yaxis=dict(tickformat=',')  # Formato con comas para separar miles (ej: 10,000)
)

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fe0be92e-5986-4b8e-a17e-60e9ac3bd7f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe0be92e-5986-4b8e-a17e-60e9ac3bd7f8")) {                    Plotly.newPlot(                        "fe0be92e-5986-4b8e-a17e-60e9ac3bd7f8",                        [{"hovertemplate":"\u003cb\u003eAño:\u003c\u002fb\u003e %{x}\u003cbr\u003e\u003cb\u003eTotal Procesos:\u003c\u002fb\u003e %{y:,}\u003cbr\u003e\u003cb\u003eVariación:\u003c\u002fb\u003e %{customdata:.2f}%","legendgroup":"","line":{"color":"teal","dash":"solid","width":2},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[5465,5990,6757,9225,9338,10048,11980,15090,22620,24291,41465,48665,67653,73688,86938],"yaxis":"y","type":"scatter","customdata":[null,9.60658737419946,12.804674457429055,36.52508509693651,1.2249322493224968,7.603341186549573,19.22770700636942,25.959933222036735,49.90059642147118,7.387267904509276,70.70108270552879,17.364041963101418,39.01777458132128,8.920520893382399,17.98121810878297]}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d857 ...

# %% [markdown]
# **Identificar los delitos informáticos más frecuentes**

# %% [markdown]
# Análisis de la Tendencia:
# Aumento gradual (2010 - 2019):
#
# Desde 2010 hasta 2019, se observa un aumento gradual en el número de procesos judiciales, con un incremento promedio anual de alrededor de 1,000 a 2,000 procesos por año. En estos años, los incrementos no son tan pronunciados, pero aún así hay un crecimiento continuo.
# Este período podría reflejar un aumento progresivo de la criminalidad o simplemente una mejoría en la capacidad del sistema judicial para procesar casos.
# Pico dramático en 2020:
#
# En 2020, los procesos judiciales aumentaron drásticamente en un 70.70%, lo que representa un aumento significativo con respecto al año anterior 7,39%).
# Este aumento es muy notable y probablemente esté relacionado con eventos extraordinarios, como la pandemia de COVID-19. Durante la pandemia, hubo un cambio en la dinámica criminal (por ejemplo, un aumento de delitos cibernéticos, fraudes en línea, entre otros) y más denuncias debido a que las personas se vieron más involucradas en situaciones de vulnerabilidad, como el uso masivo de plataformas digitales.
# También es posible que el sistema judicial se haya visto obligado a adaptarse rápidamente a nuevas realidades, como la gestión de casos a distancia (en línea), lo que podría haber permitido un mayor número de casos procesados.
# Aumento continuado en 2021-2022:
#
# En 2021 y 2022, el número de procesos sigue creciendo de manera significativa, con 48,665 en 2021 y 67,653 en 2022.
# Este crecimiento sigue en línea con la tendencia observada en 2020, aunque ya con cifras algo más estabilizadas. El aumento podría estar relacionado con un resurgimiento de denuncias después de la pandemia, el refuerzo del sistema judicial en el procesamiento de casos, o incluso la adaptación de nuevos tipos de delitos (por ejemplo, más delitos cibernéticos).
# Aumento explosivo en 2023 y 2024:
#
# En 2023 y 2024, los procesos judiciales aumentan aún más (73,688 en 2023 y 86,938 en 2024).
# Esto podría estar reflejando un aumento en la denuncia de delitos o un refuerzo en la recolección de datos y procesamiento de casos en el sistema judicial. También es probable que este aumento esté relacionado con nuevos tipos de delitos, como los delitos cibernéticos, estafas en línea, y el aumento de fraudes durante la recuperación económica post-pandemia.
# ¿Cuáles fueron los hechos más importantes?
# Para responder a esta pregunta, podemos pensar en varios factores que podrían haber influido en el aumento de procesos judiciales:
#
# Pandemia de COVID-19 (2020):
#
# La pandemia probablemente afectó el aumento de ciertos delitos, como los delitos cibernéticos (fraudes en línea, estafas bancarias, etc.), violaciones de datos personales, delitos de suplantación de identidad, entre otros. Esto se debió a la mayor dependencia de la tecnología y el uso masivo de plataformas digitales.
# Además, con las restricciones de movilidad, las personas comenzaron a realizar más actividades en línea, lo que facilitó que los delitos cibernéticos aumentaran.
# Aumento de delitos cibernéticos:
#
# Dado que el mundo se volvió más dependiente de internet durante la pandemia, se esperaría un aumento en los delitos informáticos. Esto incluye:
# Phishing
# Ransomware
# Fraudes bancarios en línea
# Ataques de DDoS
# Delitos de suplantación de identidad.
# Estos delitos tienden a crecer de manera significativa en momentos en que la digitalización se expande.
# Mejoras en el sistema judicial:
#
# Es posible que el sistema judicial colombiano haya mejorado su capacidad para procesar casos a lo largo de los años, permitiendo un mayor número de denuncias procesadas y un mejor manejo de los casos judiciales.
# Conciencia pública y facilidad para denunciar:
#
# La conciencia pública sobre la importancia de denunciar delitos y la facilidad de hacerlo en plataformas digitales también puede haber jugado un papel importante, especialmente en el contexto de delitos como fraudes en línea o estafas.
# Conclusiones:
# El aumento dramático de los procesos judiciales en 2020 y años posteriores puede estar relacionado con la pandemia y el aumento de delitos cibernéticos. La mayor digitalización y el uso de tecnologías durante la pandemia facilitaron estos delitos, y las personas comenzaron a ser más conscientes de la necesidad de denunciar.
# Este fenómeno también refleja la adaptación del sistema judicial a nuevas tecnologías y métodos de procesamiento de casos.

# %%
delitos_comunes = df_delito4.groupby("DELITO")["TOTAL_PROCESOS"].sum().sort_values(ascending=False)
print(delitos_comunes.head(10))  # Muestra los 10 delitos más comunes
# Out:
# DELITO
# HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES                                                226388
# ACCESO ABUSIVO A UN SISTEMA INFORMATICO                                                    84236
# VIOLACION DE DATOS PERSONALES                                                              69925
# SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES                                  24795
# TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDOSE DE ALGUNA MANIPULACION INFORMATICA O     24244
# INTERCEPTACION DE DATOS INFORMATICOS                                                        4972
# DAÑO INFORMATICO                                                                            3126
# USO DE SOFTWARE MALICIOSO                                                                   2820
# OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION                 2290
# MANIPULACION DE EQUIPOS MOVILES TERMINALES                                                   485
# Name: TOTAL_PROCESOS, dtype: int64

# %%
# !pip install seaborn
import seaborn as sns # importing the seaborn library
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
sns.barplot(x=delitos_comunes.head(10).index, y=delitos_comunes.head(10).values)
plt.xticks(rotation=90)
plt.title("Top 10 Delitos Informáticos más Frecuentes")
plt.xlabel("Delito")
plt.ylabel("Cantidad de Procesos")
plt.show()
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Contar la frecuencia de incidentes por DELITO
delito_count = df_delito4['DELITO'].value_counts()

# Seleccionar los 10 DELITOS más frecuentes
top_10_delito = delito_count.head(4).reset_index()


# Gráfico de líneas
plt.figure(figsize=(30, 15))
sns.lineplot(data=df_delito4, x='AÑO_HECHOS', y='TOTAL_PROCESOS', hue='DELITO', marker='o')
plt.title('Tendencia de Delitos Informáticos por Año')
plt.xlabel('Año de los Hechos')
plt.ylabel('Número Total de Procesos por tipo de delito')
plt.legend(title='top_10_delito')
plt.grid(True)
plt.show()

# %%
delitos_comunes = df_delito4.groupby("DEPARTAMENTO_HECHO")["TOTAL_PROCESOS"].sum().sort_values(ascending=False)
print(delitos_comunes.head(10))  # Muestra los 10 delitos más comunes
# Out:
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.         138221
# Antioquia              65192
# Valle del Cauca        46162
# Cundinamarca           24261
# Atlántico              21321
# Santander              17527
# Tolima                 12095
# Bolívar                10788
# Risaralda              10564
# Norte de Santander     10384
# Name: TOTAL_PROCESOS, dtype: int64

# %%
# Agrupar por Departamento y Delito y contar el número de incidentes en cada combinación
delitos_por_departamento = df_delito4.groupby(['DEPARTAMENTO_HECHO', 'DELITO'])['TOTAL_PROCESOS'].sum().unstack(fill_value=0)

# Obtener el total de delitos por departamento
top_5_departamentos = delitos_por_departamento.sum(axis=1).nlargest(5).index

# Filtrar solo los datos de esos departamentos
delitos_top5 = delitos_por_departamento.loc[top_5_departamentos]

# Mostrar las primeras filas para ver el resultado
delitos_top5.head()
# Out:
# DELITO              ACCESO ABUSIVO A UN SISTEMA INFORMATICO  DAÑO INFORMATICO  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                         21703              1175
# Antioquia                                             12799               428
# Valle del Cauca                                        8258               186
# Cundinamarca                                           7830               212
# Atlántico                                              3941               127
#
# DELITO              DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                                      29
# Antioquia                                                           6
# Valle del Cauca                                                     0
# Cundinamarca                                                       34
# Atlántico                                                           4
#
# DELITO              DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, LA INTEGRIDAD Y LA DISPONIBILIDAD DE LOS DATOS Y DE LOS SISTEMAS INFORMATICOS  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                                      11
# Antioquia                                                           1
# Valle del Cauca                                                     5
# Cundinamarca                                                       14
# Atlántico                                                           2
#
# DELITO              DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                                      18
# Antioquia                                                           3
# Valle del Cauca                                                    10
# Cundinamarca                                                      123
# Atlántico                                                           2
#
# DELITO              HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                            71442
# Antioquia                                                30696
# Valle del Cauca                                          28236
# Cundinamarca                                              9236
# Atlántico                                                12024
#
# DELITO              INTERCEPTACION DE DATOS INFORMATICOS  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                       2636
# Antioquia                                            456
# Valle del Cauca                                      254
# Cundinamarca                                         446
# Atlántico                                            272
#
# DELITO              MANIPULACION DE EQUIPOS MOVILES TERMINALES  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                               42
# Antioquia                                                   85
# Valle del Cauca                                             26
# Cundinamarca                                                25
# Atlántico                                                   13
#
# DELITO              OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                                     810
# Antioquia                                                         225
# Valle del Cauca                                                   179
# Cundinamarca                                                      161
# Atlántico                                                         169
#
# DELITO              SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                                   10255
# Antioquia                                                        3382
# Valle del Cauca                                                  1814
# Cundinamarca                                                     1496
# Atlántico                                                        1088
#
# DELITO              TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDOSE DE ALGUNA MANIPULACION INFORMATICA O  \
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                                                    8076
# Antioquia                                                        1921
# Valle del Cauca                                                  1566
# Cundinamarca                                                     1274
# Atlántico                                                        1139
#
# DELITO              USO DE SOFTWARE MALICIOSO  VIOLACION DE DATOS PERSONALES
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.                            1472                          20552
# Antioquia                                 331                          14859
# Valle del Cauca                           142                           5486
# Cundinamarca                              174                           3236
# Atlántico                                  80                           2460

# %%
delitos_top5.T.plot(kind="bar", stacked=True, figsize=(12, 6), colormap="viridis")

plt.title("Distribución de Delitos Informáticos - Top 5 Departamentos", fontsize=14)
plt.xlabel("Tipo de Delito", fontsize=12)
plt.ylabel("Número de Procesos", fontsize=12)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xticks(rotation=90)  # Rotar nombres de delitos
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.heatmap(delitos_top5, cmap="Blues", linewidths=0.5, annot=True, fmt=".0f")

plt.title("Mapa de Calor - Top 5 Departamentos con Más Delitos Informáticos", fontsize=14)
plt.xlabel("Tipo de Delito", fontsize=12)
plt.ylabel("Departamento", fontsize=12)
plt.xticks(rotation=90)  # Rotar nombres de delitos para mejor visualización
plt.show()

# %%
delitos_comunes = df_delito4.groupby("MUNICIPIO_HECHO")["TOTAL_PROCESOS"].sum().sort_values(ascending=False)
print(delitos_comunes.head(10))  # Muestra los 10 delitos más comunes
# Out:
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.     138221
# MEDELLÍN          40154
# CALI              31654
# BARRANQUILLA      16938
# CARTAGENA          9105
# BUCARAMANGA        8576
# IBAGUÉ             8445
# PEREIRA            7872
# CÚCUTA             7488
# VILLAVICENCIO      7417
# Name: TOTAL_PROCESOS, dtype: int64

# %%
# Agrupar por Municipio y Delito y contar el número de incidentes en cada combinación
delitos_por_municipio = df_delito4.groupby(['MUNICIPIO_HECHO', 'DELITO'])['TOTAL_PROCESOS'].sum().unstack(fill_value=0)

# Obtener el total de delitos por municipio
top_5_municipio = delitos_por_municipio.sum(axis=1).nlargest(5).index

# Filtrar solo los datos de esos departamentos
delito_top5 = delitos_por_municipio.loc[top_5_municipio]

# Mostrar las primeras filas para ver el resultado
delito_top5.head()
# Out:
# DELITO           ACCESO ABUSIVO A UN SISTEMA INFORMATICO  DAÑO INFORMATICO  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                       21703              1175
# MEDELLÍN                                            7594               255
# CALI                                                5511               112
# BARRANQUILLA                                        2869                99
# CARTAGENA                                           1454                63
#
# DELITO           DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                                    29
# MEDELLÍN                                                         4
# CALI                                                             0
# BARRANQUILLA                                                     2
# CARTAGENA                                                        4
#
# DELITO           DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, LA INTEGRIDAD Y LA DISPONIBILIDAD DE LOS DATOS Y DE LOS SISTEMAS INFORMATICOS  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                                    11
# MEDELLÍN                                                         1
# CALI                                                             0
# BARRANQUILLA                                                     1
# CARTAGENA                                                        2
#
# DELITO           DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                                    18
# MEDELLÍN                                                         0
# CALI                                                             2
# BARRANQUILLA                                                     1
# CARTAGENA                                                        0
#
# DELITO           HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                          71442
# MEDELLÍN                                              19793
# CALI                                                  19698
# BARRANQUILLA                                          10021
# CARTAGENA                                              4547
#
# DELITO           INTERCEPTACION DE DATOS INFORMATICOS  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                     2636
# MEDELLÍN                                          242
# CALI                                              152
# BARRANQUILLA                                      204
# CARTAGENA                                          79
#
# DELITO           MANIPULACION DE EQUIPOS MOVILES TERMINALES  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                             42
# MEDELLÍN                                                 60
# CALI                                                     13
# BARRANQUILLA                                              8
# CARTAGENA                                                 4
#
# DELITO           OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                                   810
# MEDELLÍN                                                       136
# CALI                                                           121
# BARRANQUILLA                                                   123
# CARTAGENA                                                       45
#
# DELITO           SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                                 10255
# MEDELLÍN                                                      1618
# CALI                                                          1256
# BARRANQUILLA                                                   779
# CARTAGENA                                                      265
#
# DELITO           TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDOSE DE ALGUNA MANIPULACION INFORMATICA O  \
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                                                  8076
# MEDELLÍN                                                      1254
# CALI                                                          1260
# BARRANQUILLA                                                   896
# CARTAGENA                                                     1505
#
# DELITO           USO DE SOFTWARE MALICIOSO  VIOLACION DE DATOS PERSONALES
# MUNICIPIO_HECHO
# BOGOTÁ, D.C.                          1472                          20552
# MEDELLÍN                               201                           8996
# CALI                                    96                           3433
# BARRANQUILLA                            65                           1870
# CARTAGENA                               22                           1115

# %%
delito_top5.T.plot(kind="bar", stacked=True, figsize=(12, 6), colormap="viridis")

plt.title("Distribución de Delitos Informáticos - Top 5 Municipio", fontsize=14)
plt.xlabel("Tipo de Delito", fontsize=12)
plt.ylabel("Número de Procesos", fontsize=12)
plt.legend(title="Municipio", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xticks(rotation=90)  # Rotar nombres de delitos
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.heatmap(delito_top5, cmap="Blues", linewidths=0.5, annot=True, fmt=".0f")

plt.title("Mapa de Calor - Top 5 Municipios con Más Delitos Informáticos", fontsize=14)
plt.xlabel("Tipo de Delito", fontsize=12)
plt.ylabel("Municipio", fontsize=12)
plt.xticks(rotation=90)  # Rotar nombres de delitos para mejor visualización
plt.show()

# %%
#Distribución de casos por etapa del proceso judicial
etapa_casos = df_delito4.groupby("ETAPA_CASO")["TOTAL_PROCESOS"].sum().sort_values(ascending=False)
print(etapa_casos)
# Out:
# ETAPA_CASO
# INDAGACIÓN                438184
# JUICIO                      2319
# EJECUCIÓN DE PENAS          2280
# INVESTIGACIÓN                845
# TERMINACIÓN ANTICIPADA        57
# Name: TOTAL_PROCESOS, dtype: int64

# %%
# Agrupar y sumar el total de procesos por etapa del caso
etapa_casos = df_delito4.groupby("ETAPA_CASO")["TOTAL_PROCESOS"].sum().sort_values(ascending=False)

# Calcular el porcentaje de participación
etapa_casos_percent = (etapa_casos / etapa_casos.sum()) * 100

# Combinar ambos resultados en un DataFrame
df_etapas = pd.DataFrame({"TOTAL_PROCESOS": etapa_casos, "PORCENTAJE": etapa_casos_percent})

# Mostrar los datos con los porcentajes
print(df_etapas)
# Out:
#                         TOTAL_PROCESOS  PORCENTAJE
# ETAPA_CASO
# INDAGACIÓN                      438184   98.760156
# JUICIO                            2319    0.522668
# EJECUCIÓN DE PENAS                2280    0.513878
# INVESTIGACIÓN                      845    0.190450
# TERMINACIÓN ANTICIPADA              57    0.012847

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=etapa_casos.index, y=etapa_casos.values, palette="viridis")
plt.xticks(rotation=45)
plt.title("Distribución de los Delitos por Etapa del Caso")
plt.xlabel("Etapa del Caso")
plt.ylabel("Cantidad de Procesos")
plt.show()
# Out:
# <ipython-input-56-bcc3a95ebe41>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
#Distribución de casos por etapa del proceso judicial
etapa_casos = df_delito4.groupby("ES_PRECLUSIÓN")["TOTAL_PROCESOS"].sum().sort_values(ascending=False)
print(etapa_casos)
# Out:
# ES_PRECLUSIÓN
# NO    443174
# SI       511
# Name: TOTAL_PROCESOS, dtype: int64

# %%
# Filtrar los casos que son preclusión
df_preclusion = df_delitos_informaticos_corregido[df_delitos_informaticos_corregido['ES_PRECLUSIÓN'] == 'SI']  # Ajusta este valor según cómo se registre en tus datos

# Contar los procesos precluidos y contar por departamento
top_preclusion_by_department = df_preclusion.groupby('DEPARTAMENTO_HECHO').agg(
    cantidad_preclusiones=('ES_PRECLUSIÓN', 'size'),
    total_procesos=('TOTAL_PROCESOS', 'sum')
).reset_index()
top_preclusion_by_department
# Out:
#                                    DEPARTAMENTO_HECHO  cantidad_preclusiones  \
# 0                                           Antioquia                     61
# 1                                              Arauca                      2
# 2   Archipiélago de San Andrés, Providencia y Sant...                      2
# 3                                           Atlántico                     19
# 4                                       BOGOTÁ, D. C.                     71
# 5                                             Bolívar                      9
# 6                                              Boyaca                      7
# 7                                              Caldas                     15
# 8                                             Caquetá                      9
# 9                                            Casanare                      1
# 10                                              Cauca                      9
# 11                                              Cesar                     20
# 12                                              Chocó                     25
# 13                                       Cundinamarca                     17
# 14                                            Córdoba                      9
# 15                                              Huila                      5
# 16                                         La Guajira                      2
# 17                                          Magdalena                      6
# 18                                               Meta                     15
# 19                                             Nariño                      2
# 20                                 Norte de Santander                      8
# 21                                            Quindío                     17
# 22                                          Risaralda                     35
# 23                                          Santander                     29
# 24                                              Sucre                      2
# 25                                             Tolima                     30
# 26                                    Valle del Cauca                     27
#
#     total_procesos
# 0               64
# 1                2
# 2                2
# 3               21
# 4               84
# 5                9
# 6                7
# 7               16
# 8               10
# 9                1
# 10               9
# 11              20
# 12              41
# 13              17
# 14               9
# 15               5
# 16               2
# 17               6
# 18              21
# 19               2
# 20               8
# 21              19
# 22              37
# 23              31
# 24               2
# 25              39
# 26              27

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear la gráfica
plt.figure(figsize=(12, 8))

# Crear un gráfico de barras dobles: uno para la cantidad de preclusiones y otro para el total de procesos
#sns.barplot(x='cantidad_preclusiones', y='DEPARTAMENTO_HECHO', data=top_preclusion_by_department.head(10), label='Preclusiones', color='orange')
sns.barplot(x='total_procesos', y='DEPARTAMENTO_HECHO', data=top_preclusion_by_department.head(10), label='Total Procesos', color='orange')

# Personalizar la gráfica
plt.title('Top 10 Departamentos con más Procesos Precluidos', fontsize=16)
plt.xlabel('Cantidad de Procesos precluidos', fontsize=14)
plt.ylabel('Departamento', fontsize=14)
plt.legend(title="Leyenda", loc="upper right")

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd

# Asegúrate de que 'ES_PRECLUSIÓN' tenga el formato adecuado
df_delitos_informaticos_corregido['ES_PRECLUSIÓN'] = df_delitos_informaticos_corregido['ES_PRECLUSIÓN'].str.strip().str.capitalize()

# Sumar los procesos por DEPARTAMENTO_HECHO y ES_PRECLUSIÓN
df_sum = df_delitos_informaticos_corregido.groupby(['DEPARTAMENTO_HECHO', 'ES_PRECLUSIÓN'])['TOTAL_PROCESOS'].sum().reset_index()

# Calcular el total de procesos por departamento
df_total_procesos = df_delitos_informaticos_corregido.groupby('DEPARTAMENTO_HECHO')['TOTAL_PROCESOS'].sum().reset_index()
df_total_procesos.rename(columns={'TOTAL_PROCESOS': 'TOTAL_PROCESOS_TOTALES'}, inplace=True)

# Unir los resultados con el total de procesos por departamento
df_result = pd.merge(df_sum, df_total_procesos, on='DEPARTAMENTO_HECHO')

# Calcular el porcentaje de procesos precluidos SI
df_result['PORCENTAJE'] = (df_result['TOTAL_PROCESOS'] / df_result['TOTAL_PROCESOS_TOTALES']) * 100

# Filtrar los resultados solo para 'SI' y 'NO'
df_result_si_no = df_result[df_result['ES_PRECLUSIÓN'].isin(['Si', 'No'])]

# Mostrar el resultado
print(df_result_si_no)
# Out:
#                                    DEPARTAMENTO_HECHO ES_PRECLUSIÓN  \
# 0                                            Amazonas            No
# 1                                           Antioquia            No
# 2                                           Antioquia            Si
# 3                                              Arauca            No
# 4                                              Arauca            Si
# 5   Archipiélago de San Andrés, Providencia y Sant...            No
# 6   Archipiélago de San Andrés, Providencia y Sant...            Si
# 7                                           Atlántico            No
# 8                                           Atlántico            Si
# 9                                       BOGOTÁ, D. C.            No
# 10                                      BOGOTÁ, D. C.            Si
# 11                                            Bolívar            No
# 12                                            Bolívar            Si
# 13                                             Boyaca            No
# 14                                             Boyaca            Si
# 15                                             Caldas            No
# 16                                             Caldas            Si
# 17                                            Caquetá            No
# 18                                            Caquetá            Si
# 19                                           Casanare            No
# 20                                           Casanare            Si
# 21                                              Cauca            No
# 22                                              Cauca            Si
# 23                                              Cesar            No
# 24                                              Cesar            Si
# 25                                              Chocó            No
# 26                                              Chocó            Si
# 27                                       Cundinamarca            No
# 28                                       Cundinamarca            Si
# 29                                            Córdoba            No
# 30                                            Córdoba            Si
# 31                                            Guainía            No
# 32                                           Guaviare            No
# 33                                              Huila            No
# 34                                              Huila            Si
# 35                                         La Guajira            No
# 36                                         La Guajira            Si
# 37                                          Magdalena            No
# 38                                          Magdalena            Si
# 39                                               Meta            No
# 40                                               Meta            Si
# 41                                             Nariño            No
# 42                                             Nariño            Si
# 43                                 Norte de Santander            No
# 44                                 Norte de Santander            Si
# 45                                           Putumayo            No
# 46                                            Quindío            No
# 47                                            Quindío            Si
# 48                                          Risaralda            No
# 49                                          Risaralda            Si
# 50                                          Santander            No
# 51                                          Santander            Si
# 52                                              Sucre            No
# 53                                              Sucre            Si
# 54                                             Tolima            No
# 55                                             Tolima            Si
# 56                                    Valle del Cauca            No
# 57                                    Valle del Cauca            Si
# 58                                             Vaupés            No
# 59                                            Vichada            No
#
#     TOTAL_PROCESOS  TOTAL_PROCESOS_TOTALES  PORCENTAJE
# 0              112                     112  100.000000
# 1            65128                   65192   99.901828
# 2               64                   65192    0.098172
# 3             1094                    1096   99.817518
# 4                2                    1096    0.182482
# 5              419                     421   99.524941
# 6                2                     421    0.475059
# 7            21300                   21321   99.901506
# 8               21                   21321    0.098494
# 9           138137                  138221   99.939228
# 10              84                  138221    0.060772
# 11           10779                   10788   99.916574
# 12               9                   10788    0.083426
# 13            7091                    7098   99.901381
# 14               7                    7098    0.098619
# 15            5639                    5655   99.717065
# 16              16                    5655    0.282935
# 17            2756                    2766   99.638467
# 18              10                    2766    0.361533
# 19            2641                    2642   99.962150
# 20               1                    2642    0.037850
# 21            7627                    7636   99.882137
# 22               9                    7636    0.117863
# 23            5963                    5983   99.665720
# 24              20                    5983    0.334280
# 25            1990                    2031   97.981290
# 26              41                    2031    2.018710
# 27           24244                   24261   99.929929
# 28              17                   24261    0.070071
# 29            6556                    6565   99.862909
# 30               9                    6565    0.137091
# 31              91                      91  100.000000
# 32             451                     451  100.000000
# 33            7682                    7687   99.934955
# 34               5                    7687    0.065045
# 35            1836                    1838   99.891186
# 36               2                    1838    0.108814
# 37            7495                    7501   99.920011
# 38               6                    7501    0.079989
# 39            9804                    9825   99.786260
# 40              21                    9825    0.213740
# 41            7302                    7304   99.972618
# 42               2                    7304    0.027382
# 43           10376                   10384   99.922958
# 44               8                   10384    0.077042
# 45            1364                    1364  100.000000
# 46            5003                    5022   99.621665
# 47              19                    5022    0.378335
# 48           10527                   10564   99.649754
# 49              37                   10564    0.350246
# 50           17496                   17527   99.823130
# 51              31                   17527    0.176870
# 52            3924                    3926   99.949058
# 53               2                    3926    0.050942
# 54           12056                   12095   99.677553
# 55              39                   12095    0.322447
# 56           46135                   46162   99.941510
# 57              27                   46162    0.058490
# 58              59                      59  100.000000
# 59              79                      79  100.000000

# %%
import pandas as pd

# Asegúrate de que 'ES_PRECLUSIÓN' tenga el formato adecuado
df_delitos_informaticos_corregido['ES_PRECLUSIÓN'] = df_delitos_informaticos_corregido['ES_PRECLUSIÓN'].str.strip().str.capitalize()

# Sumar los procesos por DEPARTAMENTO_HECHO y ES_PRECLUSIÓN
df_sum = df_delitos_informaticos_corregido.groupby(['DEPARTAMENTO_HECHO', 'ES_PRECLUSIÓN'])['TOTAL_PROCESOS'].sum().reset_index()

# Calcular el total de procesos por departamento
df_total_procesos = df_delitos_informaticos_corregido.groupby('DEPARTAMENTO_HECHO')['TOTAL_PROCESOS'].sum().reset_index()
df_total_procesos.rename(columns={'TOTAL_PROCESOS': 'TOTAL_PROCESOS_TOTALES'}, inplace=True)

# Unir los resultados con el total de procesos por departamento
df_result = pd.merge(df_sum, df_total_procesos, on='DEPARTAMENTO_HECHO')

# Calcular el porcentaje de procesos precluidos SI
df_result['PORCENTAJE'] = (df_result['TOTAL_PROCESOS'] / df_result['TOTAL_PROCESOS_TOTALES']) * 100

# Filtrar los resultados solo para 'SI'
df_result_si = df_result[df_result['ES_PRECLUSIÓN'] == 'Si']

# Ordenar los resultados por el porcentaje de mayor a menor
df_result_si_sorted = df_result_si.sort_values(by='PORCENTAJE', ascending=False)

# Seleccionar los 10 departamentos con el mayor porcentaje de preclusión "SI"
top_10_departamentos = df_result_si_sorted.head(10)

# Mostrar el resultado
print(top_10_departamentos)
# Out:
#                                    DEPARTAMENTO_HECHO ES_PRECLUSIÓN  \
# 26                                              Chocó            Si
# 6   Archipiélago de San Andrés, Providencia y Sant...            Si
# 47                                            Quindío            Si
# 18                                            Caquetá            Si
# 49                                          Risaralda            Si
# 24                                              Cesar            Si
# 55                                             Tolima            Si
# 16                                             Caldas            Si
# 40                                               Meta            Si
# 4                                              Arauca            Si
#
#     TOTAL_PROCESOS  TOTAL_PROCESOS_TOTALES  PORCENTAJE
# 26              41                    2031    2.018710
# 6                2                     421    0.475059
# 47              19                    5022    0.378335
# 18              10                    2766    0.361533
# 49              37                   10564    0.350246
# 24              20                    5983    0.334280
# 55              39                   12095    0.322447
# 16              16                    5655    0.282935
# 40              21                    9825    0.213740
# 4                2                    1096    0.182482

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ordenar los datos de mayor a menor por el porcentaje de preclusión
top_10_departamentos = top_10_departamentos.sort_values(by='PORCENTAJE', ascending=False)

# Crear la figura y el gráfico
plt.figure(figsize=(12, 8))

# Gráfico de barras
sns.barplot(x='PORCENTAJE', y='DEPARTAMENTO_HECHO', data=top_10_departamentos, order=top_10_departamentos['DEPARTAMENTO_HECHO'])

# Personalizar la gráfica
plt.title('Top 10 Departamentos con Mayor Porcentaje de Procesos Precluidos (SI)', fontsize=16)
plt.xlabel('Porcentaje de Procesos Precluidos (SI)', fontsize=14)
plt.ylabel('Departamento', fontsize=14)

# Agregar los porcentajes sobre las barras
for i, row in enumerate(top_10_departamentos.itertuples()):
    plt.text(row.PORCENTAJE, i, f'{row.PORCENTAJE:.1f}%', va='center', ha='left', fontsize=10)

# Mostrar la gráfica
plt.show()

# %%
# Asegúrate de que 'ES_PRECLUSIÓN' tenga el formato adecuado
df_delito4['ES_PRECLUSIÓN'] = df_delito4['ES_PRECLUSIÓN'].str.strip().str.capitalize()

# Sumar los procesos por DEPARTAMENTO_HECHO y ES_PRECLUSIÓN
df_sum1 = df_delito4.groupby(['DELITO', 'ES_PRECLUSIÓN'])['TOTAL_PROCESOS'].sum().reset_index()

# Calcular el total de procesos por departamento
df_total_procesos1 = df_delito4.groupby('DELITO')['TOTAL_PROCESOS'].sum().reset_index()
df_total_procesos1.rename(columns={'TOTAL_PROCESOS': 'TOTAL_PROCESOS_TOTALES'}, inplace=True)

# Unir los resultados con el total de procesos por departamento
df_result1 = pd.merge(df_sum1, df_total_procesos1, on='DELITO')

# Calcular el porcentaje de procesos precluidos SI
df_result1['PORCENTAJE'] = (df_result1['TOTAL_PROCESOS'] / df_result1['TOTAL_PROCESOS_TOTALES']) * 100

# Filtrar los resultados solo para 'SI' y 'NO'
df_result_si_no = df_result1[df_result1['ES_PRECLUSIÓN'].isin(['Si', 'No'])]

# Mostrar el resultado
print(df_result_si_no)
# Out:
#                                                DELITO ES_PRECLUSIÓN  \
# 0             ACCESO ABUSIVO A UN SISTEMA INFORMATICO            No
# 1             ACCESO ABUSIVO A UN SISTEMA INFORMATICO            Si
# 2                                    DAÑO INFORMATICO            No
# 3                                    DAÑO INFORMATICO            Si
# 4   DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS            No
# 5   DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, L...            No
# 6   DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, L...            Si
# 7   DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCI...            No
# 8   DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCI...            Si
# 9          HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES            No
# 10         HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES            Si
# 11               INTERCEPTACION DE DATOS INFORMATICOS            No
# 12               INTERCEPTACION DE DATOS INFORMATICOS            Si
# 13         MANIPULACION DE EQUIPOS MOVILES TERMINALES            No
# 14         MANIPULACION DE EQUIPOS MOVILES TERMINALES            Si
# 15  OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMAT...            No
# 16  OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMAT...            Si
# 17  SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS...            No
# 18  SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS...            Si
# 19  TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...            No
# 20  TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...            Si
# 21                          USO DE SOFTWARE MALICIOSO            No
# 22                          USO DE SOFTWARE MALICIOSO            Si
# 23                      VIOLACION DE DATOS PERSONALES            No
# 24                      VIOLACION DE DATOS PERSONALES            Si
#
#     TOTAL_PROCESOS  TOTAL_PROCESOS_TOTALES  PORCENTAJE
# 0            84144                   84236   99.890783
# 1               92                   84236    0.109217
# 2             3089                    3126   98.816379
# 3               37                    3126    1.183621
# 4              136                     136  100.000000
# 5               48                      49   97.959184
# 6                1                      49    2.040816
# 7              218                     219   99.543379
# 8                1                     219    0.456621
# 9           226193                  226388   99.913865
# 10             195                  226388    0.086135
# 11            4968                    4972   99.919549
# 12               4                    4972    0.080451
# 13             456                     485   94.020619
# 14              29                     485    5.979381
# 15            2278                    2290   99.475983
# 16              12                    2290    0.524017
# 17           24790                   24795   99.979835
# 18               5                   24795    0.020165
# 19           24218                   24244   99.892757
# 20              26                   24244    0.107243
# 21            2813                    2820   99.751773
# 22               7                    2820    0.248227
# 23           69823                   69925   99.854129
# 24             102                   69925    0.145871

# %%
import pandas as pd

# Asegúrate de que 'ES_PRECLUSIÓN' tenga el formato adecuado
df_delito4['ES_PRECLUSIÓN'] = df_delito4['ES_PRECLUSIÓN'].str.strip().str.capitalize()

# Sumar los procesos por DEPARTAMENTO_HECHO y ES_PRECLUSIÓN
df_sum1 = df_delito4.groupby(['DELITO', 'ES_PRECLUSIÓN'])['TOTAL_PROCESOS'].sum().reset_index()

# Calcular el total de procesos por departamento
df_total_procesos1 = df_delito4.groupby('DELITO')['TOTAL_PROCESOS'].sum().reset_index()
df_total_procesos1.rename(columns={'TOTAL_PROCESOS': 'TOTAL_PROCESOS_TOTALES'}, inplace=True)

# Unir los resultados con el total de procesos por departamento
df_result1 = pd.merge(df_sum1, df_total_procesos1, on='DELITO')

# Calcular el porcentaje de procesos precluidos SI
df_result1['PORCENTAJE'] = (df_result1['TOTAL_PROCESOS'] / df_result1['TOTAL_PROCESOS_TOTALES']) * 100

# Filtrar los resultados solo para 'SI'
df_result_si = df_result1[df_result1['ES_PRECLUSIÓN'] == 'Si']

# Ordenar los resultados por el porcentaje de mayor a menor
df_result_si_sorted = df_result_si.sort_values(by='PORCENTAJE', ascending=False)

# Seleccionar los 10 departamentos con el mayor porcentaje de preclusión "SI"
top_10_delitos_precluidos = df_result_si_sorted.head(10)

# Mostrar el resultado
print(top_10_delitos_precluidos)
# Out:
#                                                DELITO ES_PRECLUSIÓN  \
# 14         MANIPULACION DE EQUIPOS MOVILES TERMINALES            Si
# 6   DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, L...            Si
# 3                                    DAÑO INFORMATICO            Si
# 16  OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMAT...            Si
# 8   DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCI...            Si
# 22                          USO DE SOFTWARE MALICIOSO            Si
# 24                      VIOLACION DE DATOS PERSONALES            Si
# 1             ACCESO ABUSIVO A UN SISTEMA INFORMATICO            Si
# 20  TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIEND...            Si
# 10         HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES            Si
#
#     TOTAL_PROCESOS  TOTAL_PROCESOS_TOTALES  PORCENTAJE
# 14              29                     485    5.979381
# 6                1                      49    2.040816
# 3               37                    3126    1.183621
# 16              12                    2290    0.524017
# 8                1                     219    0.456621
# 22               7                    2820    0.248227
# 24             102                   69925    0.145871
# 1               92                   84236    0.109217
# 20              26                   24244    0.107243
# 10             195                  226388    0.086135

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ordenar los datos de mayor a menor por el porcentaje de preclusión
top_10_delitos_precluidos = top_10_delitos_precluidos.sort_values(by='PORCENTAJE', ascending=False)

# Crear la figura y el gráfico
plt.figure(figsize=(12, 8))

# Gráfico de barras
sns.barplot(x='PORCENTAJE', y='DELITO', data=top_10_delitos_precluidos, order=top_10_delitos_precluidos['DELITO'])

# Personalizar la gráfica
plt.title('Top 10 Departamentos con Mayor Porcentaje de Procesos Precluidos (SI)', fontsize=16)
plt.xlabel('Porcentaje de Procesos Precluidos (SI)', fontsize=14)
plt.ylabel('Departamento', fontsize=14)

# Agregar los porcentajes sobre las barras
for i, row in enumerate(top_10_delitos_precluidos.itertuples()):
    plt.text(row.PORCENTAJE, i, f'{row.PORCENTAJE:.1f}%', va='center', ha='left', fontsize=10)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# **Medidas de tendencia central**

# %% [markdown]
# ** Resumen de estadísticas generales**

# %%
df_delito4.describe(include="all")
# Out:
#        CRIMINALIDAD ES_ARCHIVO    ESTADO  ETAPA_CASO      LEY PAÍS_HECHO  \
# count         55417      55417     55417       55417    55417      55406
# unique            2          2         2           5        3          1
# top              SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# freq          43556      30354     40705       51466    54961      55406
# mean            NaN        NaN       NaN         NaN      NaN        NaN
# std             NaN        NaN       NaN         NaN      NaN        NaN
# min             NaN        NaN       NaN         NaN      NaN        NaN
# 25%             NaN        NaN       NaN         NaN      NaN        NaN
# 50%             NaN        NaN       NaN         NaN      NaN        NaN
# 75%             NaN        NaN       NaN         NaN      NaN        NaN
# max             NaN        NaN       NaN         NaN      NaN        NaN
#
#                                   SECCIONAL  \
# count                                 54952
# unique                                   50
# top     DIRECCIÓN SECCIONAL DE CUNDINAMARCA
# freq                                   5515
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                             DELITO   AÑO_ENTRADA AÑO_DENUNCIA  \
# count                                        55417  55417.000000        55408
# unique                                          13           NaN           16
# top     HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES           NaN         2024
# freq                                         17050           NaN         7854
# mean                                           NaN   2020.011838          NaN
# std                                            NaN      3.715237          NaN
# min                                            NaN   2010.000000          NaN
# 25%                                            NaN   2018.000000          NaN
# 50%                                            NaN   2021.000000          NaN
# 75%                                            NaN   2023.000000          NaN
# max                                            NaN   2025.000000          NaN
#
#                 GRUPO_DELITO  CONSUMADO    AÑO_HECHOS DEPARTAMENTO_HECHO  \
# count                  55417      55417  55417.000000              55406
# unique                     1          1           NaN                 33
# top     DELITOS INFORMATICOS  NO APLICA           NaN          Antioquia
# freq                   55417      55417           NaN               7571
# mean                     NaN        NaN   2019.629789                NaN
# std                      NaN        NaN      3.799876                NaN
# min                      NaN        NaN   2010.000000                NaN
# 25%                      NaN        NaN   2017.000000                NaN
# 50%                      NaN        NaN   2021.000000                NaN
# 75%                      NaN        NaN   2023.000000                NaN
# max                      NaN        NaN   2025.000000                NaN
#
#        MUNICIPIO_HECHO  TOTAL_PROCESOS ES_PRECLUSIÓN
# count            55406    55417.000000         55417
# unique            1017             NaN             2
# top       BOGOTÁ, D.C.             NaN            No
# freq              3481             NaN         54963
# mean               NaN        8.006298           NaN
# std                NaN       88.801123           NaN
# min                NaN        1.000000           NaN
# 25%                NaN        1.000000           NaN
# 50%                NaN        1.000000           NaN
# 75%                NaN        2.000000           NaN
# max                NaN     8715.000000           NaN

# %% [markdown]
# Interpretación:
#
# Estos resultados indican una distribución asimétrica en la cantidad de procesos por delito.*texto en cursiva*
#
# Media (8.01) → En promedio, cada delito tiene 8 procesos, pero esto puede estar influenciado por algunos valores muy altos.
#
# Mediana (1.0) → La mitad de los delitos tienen 1 solo proceso, lo que sugiere que la mayoría de los delitos son poco frecuentes.
#
# Moda (1) → El valor más común en la cantidad de procesos es 1, lo que confirma que la mayoría de los delitos registrados tienen solo un proceso.
#
# 📌 Posible interpretación:
#
# Hay muchos delitos con pocos procesos, pero algunos tienen cantidades muy altas.
#
# La media es mayor que la mediana, lo que indica una distribución sesgada a la derecha (algunos delitos tienen una cantidad desproporcionada de procesos).
#
# Posibles outliers → Es recomendable visualizar con un boxplot para ver si hay delitos con números extremos de procesos.

# %%
estadisticas_por_delito = df_delito4.groupby("DELITO")["TOTAL_PROCESOS"].agg(["mean", "median", "var", "std", "min", "max"])
estadisticas_por_departamento = df_delito4.groupby("DEPARTAMENTO_HECHO")["TOTAL_PROCESOS"].agg(["mean", "median", "var", "std", "min", "max"])

# Mostrar los delitos con más procesos en promedio
print("Top 10 delitos con mayor promedio de procesos:")
print(estadisticas_por_delito.sort_values(by="mean", ascending=False).head(10))

# Mostrar los departamentos con más procesos en promedio
print("Top 10 departamentos con mayor promedio de procesos:")
print(estadisticas_por_departamento.sort_values(by="mean", ascending=False).head(10))
# Out:
# Top 10 delitos con mayor promedio de procesos:
#                                                          mean  median  \
# DELITO
# HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES          13.277889     1.0
# ACCESO ABUSIVO A UN SISTEMA INFORMATICO              6.537017     1.0
# VIOLACION DE DATOS PERSONALES                        6.445889     1.0
# TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDO...   5.913171     1.0
# SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS ...   5.120818     1.0
# INTERCEPTACION DE DATOS INFORMATICOS                 3.305851     1.0
# USO DE SOFTWARE MALICIOSO                            3.190045     1.0
# OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATI...   2.162417     1.0
# DAÑO INFORMATICO                                     1.961104     1.0
# DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES   1.586957     1.0
#
#                                                              var         std  \
# DELITO
# HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES          21078.505447  145.184384
# ACCESO ABUSIVO A UN SISTEMA INFORMATICO              2258.266034   47.521217
# VIOLACION DE DATOS PERSONALES                        3020.198971   54.956337
# TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDO...   1349.963671   36.741852
# SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS ...   1759.800521   41.949976
# INTERCEPTACION DE DATOS INFORMATICOS                  413.194483   20.327186
# USO DE SOFTWARE MALICIOSO                             243.325110   15.598882
# OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATI...     44.988719    6.707363
# DAÑO INFORMATICO                                       40.542115    6.367269
# DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES      5.879245    2.424715
#
#                                                     min   max
# DELITO
# HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES            1  8715
# ACCESO ABUSIVO A UN SISTEMA INFORMATICO               1  2597
# VIOLACION DE DATOS PERSONALES                         1  2704
# TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDO...    1  1011
# SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS ...    1  1356
# INTERCEPTACION DE DATOS INFORMATICOS                  1   415
# USO DE SOFTWARE MALICIOSO                             1   306
# OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATI...    1   161
# DAÑO INFORMATICO                                      1   126
# DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES    1    26
# Top 10 departamentos con mayor promedio de procesos:
#                          mean  median            var         std  min   max
# DEPARTAMENTO_HECHO
# BOGOTÁ, D. C.       39.707268     1.0  107373.043306  327.678262    1  8715
# Valle del Cauca     10.327069     1.0    4235.593606   65.081438    1  2036
# Antioquia            8.610752     1.0    3036.275282   55.102407    1  2202
# Atlántico            8.597177     1.0    2498.769899   49.987697    1  1849
# Risaralda            8.057971     1.0     791.227171   28.128761    1   472
# Bolívar              6.345882     1.0     615.714315   24.813591    1   422
# Norte de Santander   5.743363     1.0     398.162103   19.954000    1   330
# Santander            5.694282     1.0     507.023503   22.517182    1   540
# Magdalena            5.568671     1.0     600.909657   24.513459    1   565
# Meta                 5.553985     1.0     467.878447   21.630498    1   342

# %% [markdown]
# **Visualización de estadísticas clave**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_delito4["TOTAL_PROCESOS"], bins=50, kde=True, color="blue")

plt.title("Distribución de Total de Procesos")
plt.xlabel("Número de Procesos")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# Interpretación del gráfico
# Distribución altamente sesgada a la derecha
#
# La mayoría de los valores están muy cerca de 0, lo que indica que la mayoría de los delitos tienen pocos procesos registrados.
#
# Hay pocos valores muy altos (outliers) que se extienden hasta más de 8000 procesos, lo que significa que unos pocos delitos acumulan la mayoría de los casos.
# Interpretación del gráfico

# %% [markdown]
# Dado que la mayoría de los datos están concentrados en valores bajos y hay algunos extremadamente altos, la distribución no se visualiza bien.
#
# Una solución es aplicar una transformación logarítmica para hacer que la distribución sea más comprensible:

# %%
import numpy as np
df_delito4["TOTAL_PROCESOS_LOG"] = np.log1p(df_delito4["TOTAL_PROCESOS"])

plt.figure(figsize=(8,5))
sns.histplot(df_delito4["TOTAL_PROCESOS_LOG"], bins=50, kde=True, color="blue")
plt.title("Distribución Logarítmica de Total de Procesos")
plt.xlabel("Log(1 + Número de Procesos)")
plt.ylabel("Frecuencia")
plt.show()

# %%
df_delito4[df_delito4["TOTAL_PROCESOS"] > 2000]  # Filtrar delitos con valores extremadamente altos
# Out:
#       CRIMINALIDAD ES_ARCHIVO    ESTADO  ETAPA_CASO      LEY PAÍS_HECHO  \
# 1741            SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 2182            SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 5069            SI         NO    ACTIVO  INDAGACIÓN  Ley 906   Colombia
# 6803            SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 7246            SI         NO    ACTIVO  INDAGACIÓN  Ley 906   Colombia
# 9678            SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 10089           SI         NO    ACTIVO  INDAGACIÓN  Ley 906   Colombia
# 11168           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 12831           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 16177           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 29356           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 30698           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 36750           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 45147           SI         SI  INACTIVO  INDAGACIÓN  Ley 906   Colombia
# 49325           SI         NO    ACTIVO  INDAGACIÓN  Ley 906   Colombia
#
#                              SECCIONAL  \
# 1741     DIRECCIÓN SECCIONAL DE BOGOTÁ
# 2182     DIRECCIÓN SECCIONAL DE BOGOTÁ
# 5069     DIRECCIÓN SECCIONAL DE BOGOTÁ
# 6803     DIRECCIÓN SECCIONAL DE BOGOTÁ
# 7246     DIRECCIÓN SECCIONAL DE BOGOTÁ
# 9678     DIRECCIÓN SECCIONAL DE BOGOTÁ
# 10089      DIRECCIÓN SECCIONAL DE CALI
# 11168      DIRECCIÓN SECCIONAL DE CALI
# 12831    DIRECCIÓN SECCIONAL DE BOGOTÁ
# 16177    DIRECCIÓN SECCIONAL DE BOGOTÁ
# 29356    DIRECCIÓN SECCIONAL DE BOGOTÁ
# 30698    DIRECCIÓN SECCIONAL DE BOGOTÁ
# 36750    DIRECCIÓN SECCIONAL DE BOGOTÁ
# 45147    DIRECCIÓN SECCIONAL DE BOGOTÁ
# 49325  DIRECCIÓN SECCIONAL DE MEDELLÍN
#
#                                            DELITO  AÑO_ENTRADA AÑO_DENUNCIA  \
# 1741                VIOLACION DE DATOS PERSONALES         2022         2022
# 2182      ACCESO ABUSIVO A UN SISTEMA INFORMATICO         2022         2022
# 5069   HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2024         2024
# 6803   HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2020         2020
# 7246   HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2023         2023
# 9678   HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2023         2023
# 10089  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2024         2024
# 11168  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2022         2022
# 12831  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2019         2019
# 16177  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2022         2022
# 29356  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2024         2024
# 30698               VIOLACION DE DATOS PERSONALES         2021         2021
# 36750  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2018         2018
# 45147  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2021         2021
# 49325  HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES         2024         2024
#
#                GRUPO_DELITO  CONSUMADO  AÑO_HECHOS DEPARTAMENTO_HECHO  \
# 1741   DELITOS INFORMATICOS  NO APLICA        2022      BOGOTÁ, D. C.
# 2182   DELITOS INFORMATICOS  NO APLICA        2022      BOGOTÁ, D. C.
# 5069   DELITOS INFORMATICOS  NO APLICA        2024      BOGOTÁ, D. C.
# 6803   DELITOS INFORMATICOS  NO APLICA        2020      BOGOTÁ, D. C.
# 7246   DELITOS INFORMATICOS  NO APLICA        2023      BOGOTÁ, D. C.
# 9678   DELITOS INFORMATICOS  NO APLICA        2023      BOGOTÁ, D. C.
# 10089  DELITOS INFORMATICOS  NO APLICA        2024    Valle del Cauca
# 11168  DELITOS INFORMATICOS  NO APLICA        2022    Valle del Cauca
# 12831  DELITOS INFORMATICOS  NO APLICA        2019      BOGOTÁ, D. C.
# 16177  DELITOS INFORMATICOS  NO APLICA        2022      BOGOTÁ, D. C.
# 29356  DELITOS INFORMATICOS  NO APLICA        2024      BOGOTÁ, D. C.
# 30698  DELITOS INFORMATICOS  NO APLICA        2021      BOGOTÁ, D. C.
# 36750  DELITOS INFORMATICOS  NO APLICA        2018      BOGOTÁ, D. C.
# 45147  DELITOS INFORMATICOS  NO APLICA        2021      BOGOTÁ, D. C.
# 49325  DELITOS INFORMATICOS  NO APLICA        2024          Antioquia
#
#       MUNICIPIO_HECHO  TOTAL_PROCESOS ES_PRECLUSIÓN  TOTAL_PROCESOS_LOG
# 1741     BOGOTÁ, D.C.            2384            No            7.776954
# 2182     BOGOTÁ, D.C.            2597            No            7.862497
# 5069     BOGOTÁ, D.C.            8715            No            9.072916
# 6803     BOGOTÁ, D.C.            4828            No            8.482395
# 7246     BOGOTÁ, D.C.            2150            No            7.673688
# 9678     BOGOTÁ, D.C.            8388            No            9.034677
# 10089            CALI            2015            No            7.608871
# 11168            CALI            2036            No            7.619233
# 12831    BOGOTÁ, D.C.            3444            No            8.144679
# 16177    BOGOTÁ, D.C.            7663            No            8.944289
# 29356    BOGOTÁ, D.C.            5354            No            8.585786
# 30698    BOGOTÁ, D.C.            2704            No            7.902857
# 36750    BOGOTÁ, D.C.            2901            No            7.973155
# 45147    BOGOTÁ, D.C.            4301            No            8.366835
# 49325        MEDELLÍN            2202            No            7.697575

# %%
# Seleccionar las dos columnas numéricas
variable_1 = df_delito4['AÑO_HECHOS']
variable_2 = df_delito4['TOTAL_PROCESOS']

# %%
# Calcular la covarianza entre las dos variables usando numpy
covarianza = np.cov(variable_1, variable_2)[0, 1]

# Imprimir el resultado
print(f'La covarianza entre AÑO_HECHOS y TOTAL_PROCESOS es: {covarianza}')
# Out:
# La covarianza entre AÑO_HECHOS y TOTAL_PROCESOS es: 7.998126962360023

# %%
# Calcular la covarianza entre las dos variables usando pandas
covarianza = df_delito4['AÑO_HECHOS'].cov(df_delito4['TOTAL_PROCESOS'])

# Imprimir el resultado
print(f'La covarianza entre AÑO_HECHOS y TOTAL_PROCESOS es: {covarianza}')
# Out:
# La covarianza entre AÑO_HECHOS y TOTAL_PROCESOS es: 7.998126962360023

# %% [markdown]
# Covarianza positiva (7.998): Cuando el valor es positivo, significa que, en general, cuando una variable aumenta, la otra también tiende a aumentar. En este caso, a medida que los años de los hechos (AÑO_HECHOS) aumentan, el número de procesos (TOTAL_PROCESOS) también tiende a aumentar.

# %%
correlacion = df_delito4["AÑO_HECHOS"].corr(df_delito4["TOTAL_PROCESOS"])
print(f"Coeficiente de correlación: {correlacion}")
# Out:
# Coeficiente de correlación: 0.02370284246429888

# %% [markdown]
# **Visualización con Boxplot**

# %%
top_delitos = df_delito4.groupby("DELITO")["TOTAL_PROCESOS"].sum().nlargest(10).index
df_filtrado = df_delito4[df_delito4["DELITO"].isin(top_delitos)]


plt.figure(figsize=(12, 6))  # Aumentar el tamaño del gráfico
sns.boxplot(x="DELITO", y="TOTAL_PROCESOS", data=df_filtrado, palette="coolwarm")
plt.xticks(rotation=45, ha="right")  # Rotar etiquetas de delitos
plt.show()
# Out:
# <ipython-input-75-a8ca475a5772>:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Interpretación:
#
# Delitos con mayor cantidad de outliers
#
# "Violación de datos personales" y "Acceso abusivo a un sistema informático" tienen muchos casos extremos.
#
# "Hurto por medios informáticos y semejantes" también muestra valores elevados.
#
# Rango de valores
#
# La mayoría de los delitos tienen pocos procesos, pero algunos superan los 8000 casos.
#
# Se confirma una distribución sesgada, con pocos delitos acumulando la mayoría de los casos.

# %%
# Matriz de correlación entre los años
correlacion = df_delitos_informaticos_corregido[['AÑO_HECHOS', 'AÑO_ENTRADA', 'AÑO_DENUNCIA']].corr()
print(correlacion)
# Out:
#               AÑO_HECHOS  AÑO_ENTRADA  AÑO_DENUNCIA
# AÑO_HECHOS      1.000000     0.959416      0.970606
# AÑO_ENTRADA     0.959416     1.000000      0.988030
# AÑO_DENUNCIA    0.970606     0.988030      1.000000

# %%
# Visualizar la matriz de correlación mediante un mapa de calor
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(correlacion, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlación entre Años')
plt.show()

# %% [markdown]
# Al analizar la correlación entre 'AÑO_HECHOS', 'AÑO_ENTRADA' y 'AÑO_DENUNCIA'. El análisis muestra una fuerte correlación positiva entre estas tres variables.Interpretación de la matriz:
# Correlación entre AÑO_HECHOS y AÑO_ENTRADA: 0.959416
#
# Este valor indica una correlación muy fuerte entre el año en que ocurrió el hecho (AÑO_HECHOS) y el año en que se registró el caso en el sistema judicial (AÑO_ENTRADA).
# Un valor de 0.96 sugiere que, en la mayoría de los casos, los hechos se registran en el sistema judicial casi en el mismo año, aunque puede haber una pequeña diferencia debido a la demora en el registro de los casos.
# Correlación entre AÑO_HECHOS y AÑO_DENUNCIA: 0.970606
#
# Este valor también es muy alto, lo que significa que hay una correlación extremadamente fuerte entre el año en que ocurrió el hecho y el año en que se denunció el delito.
# Un valor de 0.97 indica que, en la mayoría de los casos, los delitos tienden a ser denunciados en el mismo año en que ocurrieron, aunque puede haber algunos casos en los que la denuncia se haga en un año posterior.
# Correlación entre AÑO_ENTRADA y AÑO_DENUNCIA: 0.988030
#
# Este es el valor más alto de todos, lo que sugiere una correlación casi perfecta entre el año en que el caso entra al sistema judicial y el año en que se presenta la denuncia.
# Un valor de 0.99 significa que la mayoría de los casos registrados en el sistema judicial están correlacionados estrechamente con el año en que fueron denunciados. En otras palabras, los casos generalmente se registran poco después de ser denunciados.
# Conclusiones generales:
# Alta correlación: Todos los valores de correlación son muy altos (todos están por encima de 0.95), lo que sugiere que los hechos, las denuncias y los registros de entrada en el sistema judicial están muy alineados en el tiempo. Esto indica que el proceso de denuncia y el registro en el sistema judicial suelen ocurrir en el mismo año o con una pequeña diferencia temporal.
#
# Posibles retrasos: A pesar de la alta correlación, una pequeña diferencia en los valores (por ejemplo, una correlación no perfecta de 0.95 a 0.99) podría indicar algunos retrasos en el proceso de denuncia o en el registro de los hechos en el sistema. Esto podría deberse a varios factores, como la demora en la presentación de denuncias o el tiempo que tarda el sistema judicial en registrar los casos.
#
# ¿Qué significa esto para tu análisis?
# Los valores altos en la correlación pueden ser útiles si estás investigando la eficiencia del sistema judicial y el tiempo entre el hecho y su denuncia o entrada en el sistema. Un valor cercano a 1 indica que el proceso es bastante rápido y eficiente, pero si en el futuro encuentras que estas correlaciones disminuyen, podría ser una señal de que hay demoras significativas en el sistema.

# %%
# Crear tabla pivote

# Filtrar los datos entre 2010 y 2024
df_filtered = df_delito4[(df_delito4["AÑO_HECHOS"] >= 2010) & (df_delito4["AÑO_HECHOS"] <= 2024)]

delito_pivot = df_filtered.pivot_table(
    index="AÑO_HECHOS",       # Cada fila será un año
    columns="DELITO",         # Cada delito será una columna
    values="TOTAL_PROCESOS",  # Usa el total de procesos para cada delito
    aggfunc="sum",            # Sumar los valores de delitos por año
    fill_value=0              # Si no hay datos, poner 0
)

# Mostrar la tabla pivote
delito_pivot
# Out:
# DELITO      ACCESO ABUSIVO A UN SISTEMA INFORMATICO  DAÑO INFORMATICO  \
# AÑO_HECHOS
# 2010                                           1212                60
# 2011                                           1570                47
# 2012                                           1159                57
# 2013                                           1467                77
# 2014                                           1790                61
# 2015                                           1780               144
# 2016                                           1957               144
# 2017                                           2307               178
# 2018                                           3076               276
# 2019                                           3546               313
# 2020                                           6352               449
# 2021                                           7947               333
# 2022                                          14291               366
# 2023                                          14431               350
# 2024                                          20038               258
#
# DELITO      DE LA PROTECCION DE LA INFORMACION Y DE LOS DATOS  \
# AÑO_HECHOS
# 2010                                                        0
# 2011                                                        0
# 2012                                                        1
# 2013                                                        0
# 2014                                                        3
# 2015                                                        3
# 2016                                                        7
# 2017                                                       11
# 2018                                                        8
# 2019                                                       20
# 2020                                                       14
# 2021                                                       32
# 2022                                                       20
# 2023                                                        5
# 2024                                                       12
#
# DELITO      DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, LA INTEGRIDAD Y LA DISPONIBILIDAD DE LOS DATOS Y DE LOS SISTEMAS INFORMATICOS  \
# AÑO_HECHOS
# 2010                                                        1
# 2011                                                        0
# 2012                                                        2
# 2013                                                        0
# 2014                                                        0
# 2015                                                        0
# 2016                                                        1
# 2017                                                        4
# 2018                                                        2
# 2019                                                        4
# 2020                                                        5
# 2021                                                        6
# 2022                                                        3
# 2023                                                       12
# 2024                                                        9
#
# DELITO      DE LOS ATENTADOS INFORMATICOS Y OTRAS INFRACCIONES  \
# AÑO_HECHOS
# 2010                                                        9
# 2011                                                        0
# 2012                                                        1
# 2013                                                        5
# 2014                                                        1
# 2015                                                       10
# 2016                                                       15
# 2017                                                       13
# 2018                                                       16
# 2019                                                        8
# 2020                                                       14
# 2021                                                        7
# 2022                                                       66
# 2023                                                       22
# 2024                                                       31
#
# DELITO      HURTO POR MEDIOS INFORMATICOS Y SEMEJANTES  \
# AÑO_HECHOS
# 2010                                              3628
# 2011                                              3683
# 2012                                              4726
# 2013                                              6630
# 2014                                              6225
# 2015                                              6272
# 2016                                              7380
# 2017                                              9267
# 2018                                             13052
# 2019                                             13199
# 2020                                             18157
# 2021                                             22068
# 2022                                             31348
# 2023                                             35747
# 2024                                             43134
#
# DELITO      INTERCEPTACION DE DATOS INFORMATICOS  \
# AÑO_HECHOS
# 2010                                          34
# 2011                                          34
# 2012                                          54
# 2013                                          48
# 2014                                          52
# 2015                                          44
# 2016                                          47
# 2017                                          65
# 2018                                         222
# 2019                                         379
# 2020                                         957
# 2021                                         716
# 2022                                         937
# 2023                                         874
# 2024                                         478
#
# DELITO      MANIPULACION DE EQUIPOS MOVILES TERMINALES  \
# AÑO_HECHOS
# 2010                                                 0
# 2011                                                 0
# 2012                                                 3
# 2013                                                 6
# 2014                                                 2
# 2015                                                23
# 2016                                                64
# 2017                                                80
# 2018                                               102
# 2019                                                77
# 2020                                                21
# 2021                                                41
# 2022                                                48
# 2023                                                10
# 2024                                                 8
#
# DELITO      OBSTACULIZACION ILEGITIMA DEL SISTEMA INFORMATICO O RED DE TELECOMUNICACION  \
# AÑO_HECHOS
# 2010                                                       16
# 2011                                                       35
# 2012                                                       32
# 2013                                                       32
# 2014                                                       26
# 2015                                                       21
# 2016                                                       23
# 2017                                                       52
# 2018                                                       94
# 2019                                                      116
# 2020                                                      213
# 2021                                                      241
# 2022                                                      249
# 2023                                                      363
# 2024                                                      739
#
# DELITO      SUPLANTACION DE SITIOS WEB PARA CAPTURAR DATOS PERSONALES  \
# AÑO_HECHOS
# 2010                                                       46
# 2011                                                       56
# 2012                                                       55
# 2013                                                      102
# 2014                                                      150
# 2015                                                      148
# 2016                                                      184
# 2017                                                      248
# 2018                                                      782
# 2019                                                     1088
# 2020                                                     3841
# 2021                                                     3875
# 2022                                                     3595
# 2023                                                     4749
# 2024                                                     5547
#
# DELITO      TRANSFERENCIA NO CONSENTIDA DE ACTIVOS VALIENDOSE DE ALGUNA MANIPULACION INFORMATICA O  \
# AÑO_HECHOS
# 2010                                                       75
# 2011                                                       73
# 2012                                                      106
# 2013                                                      109
# 2014                                                      120
# 2015                                                      222
# 2016                                                      355
# 2017                                                      694
# 2018                                                     1197
# 2019                                                     1797
# 2020                                                     3234
# 2021                                                     3344
# 2022                                                     4094
# 2023                                                     4112
# 2024                                                     4504
#
# DELITO      USO DE SOFTWARE MALICIOSO  VIOLACION DE DATOS PERSONALES
# AÑO_HECHOS
# 2010                                5                            379
# 2011                                6                            486
# 2012                                3                            558
# 2013                               10                            739
# 2014                               16                            892
# 2015                               36                           1345
# 2016                               48                           1755
# 2017                               93                           2078
# 2018                              671                           3122
# 2019                              474                           3270
# 2020                              512                           7696
# 2021                              259                           9796
# 2022                              247                          12389
# 2023                              280                          12733
# 2024                              151                          12029

# %%
# Matriz de correlación entre distintos tipos de delitos
plt.figure(figsize=(8,6))
sns.heatmap(delito_pivot.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Matriz de Correlación entre Tipos de Delitos")
plt.show()

# %%
# Recalcular la matriz de correlación
df_corr = delito_pivot.corr()

# Crear una máscara que deja solo los valores en el rango [0.7, 1.0]
mask = (df_corr < 0.7)  # Oculta los valores menores a 0.7

# Graficar la matriz de correlación filtrada
plt.figure(figsize=(10,8))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", linewidths=0.5, vmin=0.7, vmax=1, mask=mask)
plt.title("Matriz de Correlación (Solo Correlaciones > 0.7)")
plt.show()

# %%
df_corr = delito_pivot.corr()  # Guardar la matriz de correlación

# %%
# Guardar el DataFrame df_delitos4 como un archivo CSV
df_delito4.to_csv('df_delito.csv', index=False)

# %%
dist_matrix = 1 - df_corr  # Convertimos la correlación en una distancia

# %%
# Crear el agrupamiento jerárquico

from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import linkage, dendrogram

# Convertir la matriz de distancia a un vector condensado
dist_vector = squareform(dist_matrix)

# Aplicar agrupamiento jerárquico para agrupar delitos relacionados
linkage_matrix = linkage(dist_vector, method="ward")  # Método Ward minimiza la varianza interna

# Graficar el dendrograma
plt.figure(figsize=(10, 5))
dendrogram(linkage_matrix, labels=df_corr.index, orientation="right", leaf_rotation=0, leaf_font_size=10)
plt.title("Dendrograma de Agrupamiento Jerárquico - Delitos Relacionados")
plt.xlabel("Distancia")
plt.ylabel("Delitos")
plt.show()

# %% [markdown]
# Analisis de la gráfica
# Esta gráfica es un dendrograma de agrupamiento jerárquico, utilizado para visualizar las relaciones entre diferentes tipos de delitos cibernéticos basándose en su similitud. Aquí hay algunos puntos clave sobre la imagen:
#
# Análisis del Dendrograma Estructura General:
#
# *Se observan varias ramas que conectan diferentes tipos de delitos.
# *La distancia horizontal indica cuán diferentes o similares son los delitos entre sí.
# *Mientras más temprano se unan dos elementos, más similares son.
#
# Interpretación de las Relaciones:
#
# *Delitos con conexiones cercanas (rama verde): Incluyen delitos como "hurto por medios informáticos", "acceso abusivo a un sistema informático" lo que sugiere que tienden a ocurrir juntos o compartir características.
#
# *Grupo separado (rama azul y naranja): "uso de software malicioso" y "manipulación de equipos móviles terminales" están más alejados de los otros, lo que indica que pueden ser menos similares a los demás delitos.
#
# Distancias:
#
# *Cuanto mayor sea la distancia en el eje X, más diferentes son los delitos.
# *En este caso, los delitos en la parte inferior derecha están más separados del resto, sugiriendo que tienen características distintivas.
#
# Posibles Aplicaciones:
# *Agrupar delitos similares para desarrollar estrategias de prevención y respuesta.
# *Analizar tendencias en los ciberdelitos según su relación.
# *Optimizar recursos para combatir grupos de delitos relacionados en lugar de analizarlos de forma aislada.
#
# Basado en el dendrograma de agrupamiento jerárquico de delitos informáticos en Colombia, se pueden diseñar estrategias de mitigación y protección de la seguridad digital enfocadas en los grupos de delitos más relacionados.
#
# A continuación, se proponen estrategias y mecanismos según las agrupaciones observadas en la gráfica.
#
# Clúster 1: Acceso, hurto y manipulación de sistemas
#
# Delitos agrupados:
# *Hurto por medios informáticos y semejantes
# *Acceso abusivo a un sistema informático
# *Obstaculización ilegítima del sistema informático
# *Violación de datos personales
# *Transferencia no consentida de activos
# *Suplantación de sitios web
# *DE LOS ATENTADOS CONTRA LA CONFIDENCIALIDAD, LA INTEGRIDAD Y LA DISPONIBILIDAD DE LOS DATOS Y DE LOS SISTEMAS INFORMATICOS
# *De los atentados informáticos y otras infracciones.
#
#
# Estrategias y mecanismos:
#
# Autenticación multifactor (MFA): para proteger accesos a sistemas críticos.
#
# Segmentación de red y control de acceso (NAC): restringe movimientos laterales y accesos no autorizados.
#
# Detección de intrusiones (IDS/IPS): monitoreo constante del tráfico para detectar accesos indebidos.
#
# Concienciación y formación a usuarios: para prevenir phishing, ingeniería social y suplantación web.
#
# Protección de endpoints: uso de EDR para detectar actividades anómalas o maliciosas.
#
# Clúster 2: Daños e interferencias al sistema Delitos agrupados:
#
# *Interceptación de datos informaticos
# *Daño informático
# *De la proteccion de la información y de los datos
#
# Estrategias y mecanismos:
#
# Antimalware actualizado: para detectar y detener amenazas antes de causar daño.
#
# Control de dispositivos USB y móviles (MDM): restringir y monitorear el uso de dispositivos externos.
#
# Backups automáticos y protegidos: para recuperación ante ataques destructivos como ransomware.
#
# Política de parches y actualizaciones: evitar que vulnerabilidades sean explotadas.
#
# Clúster 3: Protección de datos e integridad de la información Delitos agrupados:
#
# *Uso de software malicioso
# *Manipulación de equipos moviles terminales
#
# Estrategias y mecanismos:
#
# Cifrado de datos en reposo y en tránsito: protege la confidencialidad y la integridad.
#
# Clasificación de la información: para aplicar controles según el nivel de sensibilidad.
#
# Gestión de identidades y privilegios (IAM): acceso a información solo para quienes lo requieran.
#
# Auditorías y monitoreo continuo (SIEM): detección proactiva de alteraciones en la integridad de los sistemas.
#
# Recomendaciones transversales para Colombia:
#
# *Fortalecer el marco legal
#
# *Campañas de educación digital nacional: lideradas por MinTIC, enfocar en jóvenes, empresas y entidades públicas.
#
# *Colaboración público-privada: crear Centros de Respuesta a Incidentes Regionales (CSIRT) apoyados por empresas tecnológicas.
#
# *Desarrollo de talento en ciberseguridad: inversión en formación técnica y universitaria.
#
# *Certificaciones para operadores críticos (CII): exigir cumplimiento de estándares como ISO/IEC 27001, IEC 62443, NIST CSF.

# %%
from google.colab import files

# Descargar el archivo CSV a tu computadora
files.download('df_delito.csv') # Changed the filename to match saved filename
